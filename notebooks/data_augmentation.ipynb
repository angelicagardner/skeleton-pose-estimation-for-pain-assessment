# %% [markdown]
# # Data Augmentation

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf 
import tensorflow_addons as tfa

from pathlib import Path
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import KFold
from sklearn.metrics import precision_recall_fscore_support, roc_auc_score, accuracy_score
from tensorflow.keras.layers import Input, LSTM, Dense, Flatten, TimeDistributed, Conv1D, BatchNormalization, MaxPooling1D, ConvLSTM1D, Bidirectional, Concatenate
from tensorflow.keras import Model
from tensorflow.keras.initializers import Constant
from keras.layers.advanced_activations import PReLU

# %% [markdown]
# ## Methods for loading datasets and creating model architectures

# %%
def load_file(file):
    df = pd.read_csv(file, header=0)
    labels = df['pain']
    df = df.drop(columns=['pain'])
    df.drop(df.columns[-1], axis=1, inplace=True)
    return df, labels

def load_dataset(input_filepath, modality):
    feature_names = []
    classes = []
    root_dir = Path(os.path.abspath('')).parent
    data_dir = root_dir / 'data'
    train_filepath = data_dir / input_filepath / 'train' / modality
    test_filepath = data_dir / input_filepath / 'test' / modality
    # 1. Load train data
    X = list()
    y = list()
    for file in train_filepath.iterdir():
        if file.is_file() and file.name.endswith('.csv'):
            x, labels = load_file(file)
            if feature_names == []:
                feature_names = x.columns.values.tolist()
            if labels[0] not in classes:
                classes.append(labels[0])
            x = x.to_numpy()
            X.append(x)
            y.append(labels[0])
    n_length = X[0].shape[0]
    n_features = X[0].shape[1]
    X = np.array(X)
    X_train = X.reshape((len(X), 1, n_length, n_features))
    lb = LabelBinarizer()
    y_train = lb.fit_transform(y)
    # 2. Load test data
    X = list()
    y = list()
    for file in test_filepath.iterdir():
        if file.is_file() and file.name.endswith('.csv'):
            x, labels = load_file(file)
            x = x.to_numpy()
            X.append(x)
            y.append(labels[0])
    n_length = X[0].shape[0]
    n_features = X[0].shape[1]
    X = np.array(X)
    X_test = X.reshape((len(X), 1, n_length, n_features))
    y_test = lb.transform(y)
    return X_train, X_test, y_train, y_test, feature_names, classes

def load_earlyfusion_dataset(input_filepath):
    root_dir = Path(os.path.abspath('')).parent
    data_dir = root_dir / 'data'
    body_train_filepath = data_dir / input_filepath / 'train' / 'skeleton'
    body_test_filepath = data_dir / input_filepath / 'test' / 'skeleton'
    face_train_filepath = data_dir / input_filepath / 'train' / 'AUs'
    face_test_filepath = data_dir / input_filepath / 'test' / 'AUs'
    # 1. Load train data
    X = list()
    y = list()
    for file in body_train_filepath.iterdir():
        if file.is_file() and file.name.endswith('.csv'):
            body_x, body_labels = load_file(file)
            has_equivalent_face_file = False
            for second_file in face_train_filepath.iterdir():
                if second_file.is_file() and second_file.name.endswith('.csv') and second_file.name == file.name:
                    # Concatenate features
                    face_x, face_labels = load_file(second_file)
                    full_X = np.concatenate((body_x, face_x), axis=1)
                    body_x = body_x.to_numpy()
                    face_x = face_x.to_numpy()
                    X.append(full_X)
                    y.append(body_labels[0])
                    has_equivalent_face_file = True
                    break
            if not has_equivalent_face_file:
                continue
    n_length = X[0].shape[0]
    n_features = X[0].shape[1]
    X = np.array(X)
    X_train = X.reshape((len(X), 1, n_length, n_features))
    lb = LabelBinarizer()
    y_train = lb.fit_transform(y)
    # 2. Load test data
    X = list()
    y = list()
    for file in body_test_filepath.iterdir():
        if file.is_file() and file.name.endswith('.csv'):
            body_x, body_labels = load_file(file)
            body_x = body_x.to_numpy()
            has_equivalent_face_file = False
            for second_file in face_test_filepath.iterdir():
                if second_file.is_file() and second_file.name.endswith('.csv') and second_file.name == file.name:
                    # Concatenate features
                    face_x, face_labels = load_file(second_file)
                    face_x = face_x.to_numpy()
                    full_X = np.concatenate((body_x, face_x), axis=1)
                    X.append(full_X)
                    y.append(body_labels[0])
                    has_equivalent_face_file = True
                    break
            if not has_equivalent_face_file:
                continue
    n_length = X[0].shape[0]
    n_features = X[0].shape[1]
    X = np.array(X)
    X_test = X.reshape((len(X), 1, n_length, n_features))
    y_test = lb.transform(y)
    return X_train, X_test, y_train, y_test

def load_latefusion_dataset(input_filepath, modality):
    root_dir = Path(os.path.abspath('')).parent
    data_dir = root_dir / 'data'
    train_filepath = data_dir / input_filepath / 'train' / modality
    test_filepath = data_dir / input_filepath / 'test' / modality
    # 1. Load train data
    X = list()
    y = list()
    for file in train_filepath.iterdir():
        if file.is_file() and file.name.endswith('.csv'):
            x, labels = load_file(file)
            if modality == 'skeleton':
                has_equivalent_face_file = False 
                for second_file in (data_dir / input_filepath / 'train' / 'AUs').iterdir():
                    if second_file.is_file() and second_file.name.endswith('.csv') and second_file.name == file.name:
                        has_equivalent_face_file = True
                        break
                if not has_equivalent_face_file:
                    continue
                else: 
                    x = x.to_numpy()
                    X.append(x)
                    y.append(labels[0])
            else:
                x = x.to_numpy()
                X.append(x)
                y.append(labels[0])
    n_length = X[0].shape[0]
    n_features = X[0].shape[1]
    X = np.array(X)
    X_train = X.reshape((len(X), 1, n_length, n_features))
    lb = LabelBinarizer()
    y_train = lb.fit_transform(y)
    # 2. Load test data
    X = list()
    y = list()
    for file in test_filepath.iterdir():
        if file.is_file() and file.name.endswith('.csv'):
            x, labels = load_file(file)
            if modality == 'skeleton':
                has_equivalent_face_file = False 
                for second_file in (data_dir / input_filepath / 'test' / 'AUs').iterdir():
                    if second_file.is_file() and second_file.name.endswith('.csv') and second_file.name == file.name:
                        has_equivalent_face_file = True
                        break
                if not has_equivalent_face_file:
                    continue
                else: 
                    x = x.to_numpy()
                    X.append(x)
                    y.append(labels[0])
            else:
                x = x.to_numpy()
                X.append(x)
                y.append(labels[0])
    n_length = X[0].shape[0]
    n_features = X[0].shape[1]
    X = np.array(X)
    X_test = X.reshape((len(X), 1, n_length, n_features))
    y_test = lb.transform(y)
    return X_train, X_test, y_train, y_test

# %%
class KerasMember():
    def __init__(self, name=None, keras_model=None, train_batches=None,
                 val_batches=None, submission_probs=None, keras_modelpath=None,
                 keras_kwargs={}):
        assert(name is not None)
        self.name = name
        self.model = keras_model
        self.submission_probs = submission_probs
        # Initialize Params
        self.val_probs = None
        self.train_probs = None
        self.val_classes = None
        self.train_classes = None
        if (keras_model is None) and (keras_modelpath is not None):
            self.load_kerasmodel(self.keras_modelpath, self.keras_kwargs)
        if train_batches is not None:
            self._calculate_train_predictions(train_batches)
        if val_batches is not None:
            self._calculate_val_predictions(val_batches)

    def _test_datatuple(self, datatuple):
        assert(len(datatuple) == 2)
        assert(datatuple[0].shape[0] == datatuple[1].shape[0])

    def _calculate_predictions(self, batches):
        if hasattr(batches, 'shuffle'):
            batches.reset()
            batches.shuffle = False
        if type(batches) is tuple:
            self._test_datatuple(batches)
            return self.model.predict(batches[0])
        return self.model.predict_generator(
            batches, steps=(batches.n // batches.batch_size) + 1, verbose=1)

    def _calculate_val_predictions(self, val_batches):
        if type(val_batches) is tuple:
            self.val_classes = val_batches[1]
        elif hasattr(val_batches, 'classes'):
            self.val_classes = np.array(val_batches.classes)
        elif hasattr(val_batches, 'y'):
            self.val_classes = np.array(val_batches.y)
        else:
            raise ValueError("No known class in data batch")
        self.val_probs = self._calculate_predictions(val_batches)
        return self.val_probs

    def _calculate_train_predictions(self, train_batches):
        if type(train_batches) is tuple:
            self.train_classes = train_batches[1]
        elif hasattr(train_batches, 'classes'):
            self.train_classes = np.array(train_batches.classes)
        elif hasattr(train_batches, 'y'):
            self.train_classes = np.array(train_batches.y)
        else:
            raise ValueError("No known class in data batch")
        self.train_probs = self._calculate_predictions(train_batches)
        return self.train_probs

# %%
def train(model, X_train, y_train, X_val, y_val, epochs, batch_size, class_weight):
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=10)
    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=epochs, callbacks=[early_stopping],
        batch_size=batch_size, verbose=2, class_weight=class_weight)
    return history

def train_fusioned(model, body_X_train, face_X_train, y_train, body_X_val, face_X_val, y_val, epochs, batch_size, class_weight):
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=10)
    history = model.fit([body_X_train, face_X_train], y_train, validation_data=([body_X_val, face_X_val], y_val), 
                        epochs=epochs, batch_size=batch_size, callbacks=[early_stopping], class_weight=class_weight, verbose=2)
    return history

# %% [markdown]
# ### Bidirectional LSTM Model
#
# Bidrectional LSTM runs the input in two ways (past to future and future to past) making it possible to preserve information both backwards and forwards. I included this layer type anticipating it could be suited for making the model understand context to assess any experience of pain.
#
# Additionally, bidrectional LSTM is used by [Bargshady et al.](https://pubmed.ncbi.nlm.nih.gov/34756219/) in an Ensemble combination of CNN+BiLSTM models for facial expressions modality. Their settings:
#
# - filters: 256
# - dense: 4096

# %%
def build_biConvLSTM(n_features, n_length, n_outputs):
    input = Input(shape=(1, n_length, n_features))
    bilstm_1 = Bidirectional(ConvLSTM1D(filters=100, kernel_size=(3), activation='relu', return_sequences=True))(input)
    bilstm_2 = Bidirectional(ConvLSTM1D(filters=100, kernel_size=(3), activation='relu', return_sequences=True))(bilstm_1)
    bilstm_3 = Bidirectional(ConvLSTM1D(filters=100, kernel_size=(3), activation='relu'))(bilstm_2)
    flatten = Flatten()(bilstm_3)
    dense = Dense(100, activation='relu')(flatten)
    dense = Dense(100, activation='relu')(flatten)
    output = Dense(units=n_outputs, activation='softmax')(dense)
    model = Model(inputs=input, outputs=output)
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.F1Score(num_classes=n_outputs, average='macro')])
    return model

def build_fusioned_biConvLSTM(body_features, face_features, n_length, n_outputs):
    input_1 = Input(shape=(1, n_length, body_features))
    bilstm_1 = Bidirectional(ConvLSTM1D(filters=100, kernel_size=(3), activation='relu', return_sequences=True))(input_1)
    bilstm_11 = Bidirectional(ConvLSTM1D(filters=100, kernel_size=(3), activation='relu', return_sequences=True))(bilstm_1)
    bilstm_111 = Bidirectional(ConvLSTM1D(filters=100, kernel_size=(3), activation='relu'))(bilstm_11)
    flatten_1 = Flatten()(bilstm_111)
    dense_1 = Dense(100, activation='relu')(flatten_1)
    dense_11 = Dense(100, activation='relu')(dense_1)

    input_2 = Input(shape=(1, n_length, face_features))
    bilstm_2 = Bidirectional(ConvLSTM1D(filters=100, kernel_size=(3), activation='relu', return_sequences=True))(input_2)
    bilstm_22 = Bidirectional(ConvLSTM1D(filters=100, kernel_size=(3), activation='relu', return_sequences=True))(bilstm_2)
    bilstm_222 = Bidirectional(ConvLSTM1D(filters=100, kernel_size=(3), activation='relu'))(bilstm_22)
    flatten_2 = Flatten()(bilstm_222)
    dense_2 = Dense(100, activation='relu')(flatten_2)
    dense_22 = Dense(100, activation='relu')(dense_2)

    concat = Concatenate()([dense_11, dense_22])
    output = Dense(units=n_outputs, activation='softmax')(concat)
    model = Model(inputs=[input_1, input_2], outputs=[output])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.F1Score(num_classes=n_outputs, average='macro')])
    return model

# %% [markdown]
# ### CNN+LSTM Model
#
# This combination was developed for visual time series prediction problems and is popular in both activity recognition and pain assessment areas.
#
# Several previous work has used CNN+LSTM models, for example:
#
# - [Yang et al.](https://arxiv.org/abs/2105.08822) to encode appearance changes and physiological cues from videos.
#
# - [Salekin et al.](https://arxiv.org/abs/2012.02175). Combines three modalities with (late) decision fusion. CNN filters start at 64 and gradually increses by a factor of 2 until 512. Used a small kernel size of 3, and follow with a pooling layer. Dense: 512. LSTM: 16 with activation tanh and recurrent activation hard sigmoid (because of binary classification).
#
# - [Haque et al.](https://ieeexplore-ieee-org.proxy.lnu.se/document/8373837) extracts RGB, thermal, depth features from videos and test two fusion strategies (early fusion received highest performance). LSTM hidden states vary between 64 and 256.
#
# - [Rodriguez et al.](https://ieeexplore-ieee-org.proxy.lnu.se/document/7849133). Trying to make an end-to-end framework using VGGFace architecture + LSTM.

# %%
def build_CNN(n_features, n_length, n_outputs):
    input = Input(shape=(1, n_length, n_features))
    conv1d_1 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'))(input)
    conv1d_2 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'))(conv1d_1)
    maxpool_1 = TimeDistributed(MaxPooling1D(pool_size=2, data_format='channels_first'))(conv1d_2)
    conv1d_3 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'))(maxpool_1)
    conv1d_4 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'))(conv1d_3)
    maxpool_2 = TimeDistributed(MaxPooling1D(pool_size=2, data_format='channels_first'))(conv1d_4)
    flatten = TimeDistributed(Flatten())(maxpool_2)
    lstm_1 = LSTM(100, return_sequences=True)(flatten)
    lstm_2 = LSTM(100)(lstm_1)
    dense_1 = Dense(100, activation='relu')(lstm_2)
    dense_2 = Dense(100, activation='relu')(dense_1)
    output = Dense(units=n_outputs, activation='softmax')(dense_2)
    model = Model(inputs=input, outputs=output)
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.F1Score(num_classes=n_outputs, average='macro')])
    return model

def build_fusioned_CNN(body_features, face_features, n_length, n_outputs):
    input_1 = Input(shape=(1, n_length, body_features))
    conv1d_1 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'))(input_1)
    conv1d_11 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'))(conv1d_1)
    maxpool_1 = TimeDistributed(MaxPooling1D(pool_size=2, data_format='channels_first'))(conv1d_11)
    conv1d_111 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'))(maxpool_1)
    conv1d_1111 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'))(conv1d_111)
    maxpool_11 = TimeDistributed(MaxPooling1D(pool_size=2, data_format='channels_first'))(conv1d_1111)
    flatten_1 = TimeDistributed(Flatten())(maxpool_11)
    lstm_1 = LSTM(100, return_sequences=True)(flatten_1)
    lstm_11 = LSTM(100)(lstm_1)
    dense_1 = Dense(100, activation='relu')(lstm_11)
    dense_11 = Dense(100, activation='relu')(dense_1)

    input_2 = Input(shape=(1, n_length, face_features))
    conv1d_2 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'))(input_2)
    conv1d_22 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'))(conv1d_2)
    maxpool_2 = TimeDistributed(MaxPooling1D(pool_size=2, data_format='channels_first'))(conv1d_22)
    conv1d_222 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'))(maxpool_2)
    conv1d_2222 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation='relu'))(conv1d_222)
    maxpool_22 = TimeDistributed(MaxPooling1D(pool_size=2, data_format='channels_first'))(conv1d_2222)
    flatten_2 = TimeDistributed(Flatten())(maxpool_22)
    lstm_2 = LSTM(100, return_sequences=True)(flatten_2)
    lstm_22 = LSTM(100)(lstm_2)
    dense_2 = Dense(100, activation='relu')(lstm_22)
    dense_22 = Dense(100, activation='relu')(dense_2)

    concat = Concatenate()([dense_11, dense_22])
    output = Dense(units=n_outputs, activation='softmax')(concat)
    model = Model(inputs=[input_1, input_2], outputs=[output])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.F1Score(num_classes=n_outputs, average='macro')])
    return model

# %% [markdown]
# ### Convolutional LSTM Model
#
# A CNN-LSTM (model above) is an integration of a CNN with an LSTM, but ConvLSTM is a kind of LSTM which replaces the matrix multiplication with convolution operation at each gate in the LSTM cell.
#
# I have not encountered this layer type when preparing the training protocol (from previous work), but I find it interesting to see if it could give different results.

# %%
def build_convLSTM(n_features, n_length, n_outputs):
    input = Input(shape=(1, n_length, n_features))
    convlstm_1 = ConvLSTM1D(filters=64, kernel_size=(3), activation='relu', return_sequences=True)(input)
    convlstm_2 = ConvLSTM1D(filters=64, kernel_size=(3), activation='relu')(convlstm_1)
    flatten = Flatten()(convlstm_2)
    dense_1 = Dense(100, activation='relu')(flatten)
    dense_2 = Dense(100, activation='relu')(dense_1)
    output = Dense(units=n_outputs, activation='softmax')(dense_2)
    model = Model(inputs=input, outputs=output)
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.F1Score(num_classes=n_outputs, average='macro')])
    return model

def build_fusioned_convLSTM(body_features, face_features, n_length, n_outputs):
    input_1 = Input(shape=(1, n_length, body_features))
    convlstm_1 = ConvLSTM1D(filters=64, kernel_size=(3), activation='relu', return_sequences=True)(input_1)
    convlstm_11 = ConvLSTM1D(filters=64, kernel_size=(3), activation='relu')(convlstm_1)
    flatten_1 = Flatten()(convlstm_11)
    dense_1 = Dense(100, activation='relu')(flatten_1)
    dense_11 = Dense(100, activation='relu')(dense_1)

    input_2 = Input(shape=(1, n_length, face_features))
    convlstm_2 = ConvLSTM1D(filters=64, kernel_size=(3), activation='relu', return_sequences=True)(input_2)
    convlstm_22 = ConvLSTM1D(filters=64, kernel_size=(3), activation='relu')(convlstm_2)
    flatten_2 = Flatten()(convlstm_22)
    dense_2 = Dense(100, activation='relu')(flatten_2)
    dense_22 = Dense(100, activation='relu')(dense_2)

    concat = Concatenate()([dense_11, dense_22])
    output = Dense(units=n_outputs, activation='softmax')(concat)
    model = Model(inputs=[input_1, input_2], outputs=[output])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.F1Score(num_classes=n_outputs, average='macro')])
    return model

# %% [markdown]
# ### RCNN (Recurrent CNN) Model
#
# A network that has both convolutional and recurrent convolutional layers, or adding recurrent connections within every convolutional layer of a feed-forward CNN.
#
# Additionally, RCNN is used by [Zhou et al.](https://ieeexplore-ieee-org.proxy.lnu.se/document/7789681) with video input for pain intensity prediction using PSPI.

# %%
def build_RCNN(n_features, n_length, n_outputs):
   input = Input(shape=(1, n_length, n_features))
   conv1d_1 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation=PReLU(alpha_initializer=Constant(value=0.25))))(input)
   bn_1 = TimeDistributed(BatchNormalization())(conv1d_1)
   maxpool_1 = TimeDistributed(MaxPooling1D(pool_size=2, data_format='channels_first'))(bn_1)
   conv1d_2 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation=PReLU(alpha_initializer=Constant(value=0.25))))(maxpool_1)
   bn_2 = TimeDistributed(BatchNormalization())(conv1d_2)
   maxpool_2 = TimeDistributed(MaxPooling1D(pool_size=2, data_format='channels_first'))(bn_2)
   flatten = Flatten()(maxpool_2)
   dense_1 = Dense(256)(flatten)
   dense_2 = Dense(256)(dense_1)
   output = Dense(units=n_outputs, activation='softmax')(dense_2)
   model = Model(inputs=input, outputs=output)
   model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.F1Score(num_classes=n_outputs, average='macro')])
   return model

def build_fusioned_RCNN(body_features, face_features, n_length, n_outputs):
   input_1 = Input(shape=(1, n_length, body_features))
   conv1d_1 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation=PReLU(alpha_initializer=Constant(value=0.25))))(input_1)
   bn_1 = TimeDistributed(BatchNormalization())(conv1d_1)
   maxpool_1 = TimeDistributed(MaxPooling1D(pool_size=2, data_format='channels_first'))(bn_1)
   conv1d_11 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation=PReLU(alpha_initializer=Constant(value=0.25))))(maxpool_1)
   bn_11 = TimeDistributed(BatchNormalization())(conv1d_11)
   maxpool_11 = TimeDistributed(MaxPooling1D(pool_size=2, data_format='channels_first'))(bn_11)
   flatten_1 = Flatten()(maxpool_11)
   dense_1 = Dense(256)(flatten_1)
   dense_11 = Dense(256)(dense_1)

   input_2 = Input(shape=(1, n_length, face_features))
   conv1d_2 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation=PReLU(alpha_initializer=Constant(value=0.25))))(input_2)
   bn_2 = TimeDistributed(BatchNormalization())(conv1d_2)
   maxpool_2 = TimeDistributed(MaxPooling1D(pool_size=2, data_format='channels_first'))(bn_2)
   conv1d_22 = TimeDistributed(Conv1D(filters=64, kernel_size=3, activation=PReLU(alpha_initializer=Constant(value=0.25))))(maxpool_2)
   bn_22 = TimeDistributed(BatchNormalization())(conv1d_22)
   maxpool_22 = TimeDistributed(MaxPooling1D(pool_size=2, data_format='channels_first'))(bn_22)
   flatten_2 = Flatten()(maxpool_22)
   dense_2 = Dense(256)(flatten_2)
   dense_22 = Dense(256)(dense_2)

   concat = Concatenate()([dense_11, dense_22])
   output = Dense(units=n_outputs, activation='softmax')(concat)
   model = Model(inputs=[input_1, input_2], outputs=[output])
   model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.F1Score(num_classes=n_outputs, average='macro')])
   return model

# %% [markdown]
# ### Dirichlet Markov Ensemble with soft voting
#
# The Dirichlet ensemble weights the ensemble members based on validation set performance. The weight optimization search is performed with randomized search based on the dirichlet distribution.
#
# Soft voting involves summing the predicted probability scores for each class label and predicting the class label with the largest probability.

# %%
class DirichletEnsemble():
    def __init__(self, N=10000, metric=None, maximize=True):
        self.n = N
        self.metric = metric
        if metric is None:
            self.metric = roc_auc_score
        self.maximize = maximize
        # Initialize Parameters:
        self.members = []
        self.bestweights = []
        self.probabilities = None
        self._nmembers = 0
        self.bestscore = float("-inf") if maximize else float("inf")
        self.accuracy = None
        self.precision = None
        self.recall = None
        self.f1 = None
        self.fitted = False

    def add_members(self, members):
        for member in members:
            self.add_member(member)

    def add_member(self, member):
        self.members.append(member)
        self._nmembers += 1

    def fit(self, verbose=False):
        assert(len(self.members) > 1)
        val_classes = self.members[0].val_classes
        best_ensemble_score = float("-inf") if self.maximize else float("inf")
        best_ensemble_accuracy = 0
        best_ensemble_p = 0
        best_ensemble_r = 0
        best_ensemble_f1 = 0
        rsbest = None
        for i in range(self.n):
            rs = np.random.dirichlet(np.ones(self._nmembers), size=1)[0]
            preds = np.sum(np.array([self.members[i].val_probs * rs[i]
                                     for i in range(self._nmembers)]), axis=0)
            ensemble_score = _calculate_metric(val_classes, preds)
            ensemble_accuracy = _calculate_metric(val_classes, preds, accuracy_score)
            ensemble_prf1 = _calculate_metric(val_classes, preds, precision_recall_fscore_support)
            ensemble_p = ensemble_prf1[0]
            ensemble_r = ensemble_prf1[1]
            ensemble_f1 = ensemble_prf1[2]
            max_flag = self.maximize and ensemble_score > best_ensemble_score
            min_flag = not(
                self.maximize) and ensemble_score < best_ensemble_score
            if max_flag or min_flag:
                if verbose:
                    print(ensemble_score, i, rs) 
                best_ensemble_score = ensemble_score
                rsbest = rs
            if ensemble_accuracy > best_ensemble_accuracy:
                if verbose:
                    print(ensemble_accuracy, i, rs) 
                best_ensemble_accuracy = ensemble_accuracy
            if ensemble_p > best_ensemble_p:
                if verbose:
                    print(ensemble_p, i, rs) 
                best_ensemble_p = ensemble_p
            if ensemble_r > best_ensemble_r:
                if verbose:
                    print(ensemble_r, i, rs) 
                best_ensemble_r = ensemble_r
            if ensemble_f1 > best_ensemble_f1:
                if verbose:
                    print(ensemble_f1, i, rs) 
                best_ensemble_f1 = ensemble_f1
        self.bestweights = rsbest
        self.bestscore = best_ensemble_score
        self.accuracy = best_ensemble_accuracy
        self.precision = best_ensemble_p
        self.recall = best_ensemble_r
        self.f1 = best_ensemble_f1

    def predict(self):
        self.probabilities = np.sum(np.array([self.bestweights[i] *
                                              self.members[i].submission_probs
                                              for i in range(self._nmembers)]),
                                    axis=0)
        return self.probabilities
        
    def describe(self):
        for i in range(self._nmembers):
            member = self.members[i]
            text = member.name + " (weight: {:1.4f})".format(self.bestweights[i])
            print(text)
        print("Accuracy: {:1.2f}% - ROC/AUC: {:1.2f} - Precision: {:1.2f} - Recall: {:1.2f} - F1 score: {:1.2f}".format(
            self.accuracy * 100, self.bestscore, self.precision, self.recall, self.f1))
        return

def _calculate_metric(y_true, y_pred, metric=None):
    if metric is None:
        metric = roc_auc_score
    y_t = y_true
    y_p = y_pred
    if metric == roc_auc_score:
        return metric(y_t, y_p, multi_class='ovo')
    if y_true.ndim > 1:
        y_t = np.argmax(y_true, axis=1)
    if y_pred.ndim > 1:
        y_p = np.argmax(y_pred, axis=1)
    if metric is precision_recall_fscore_support:
        return precision_recall_fscore_support(y_t, y_p, average='macro')
    return metric(y_t, y_p)

# %% [markdown]
# ### KFold CV

# %%
kf = KFold(n_splits=3, shuffle=True, random_state=42)
epochs, batch_size = 50, 32

# %% [markdown]
# ## 1. Uni-modal approaches
#
# Training the different model architectures on single modalities (skeleton vs action units).

# %% [markdown]
# ### About the data

# %%
full_body_X_train, full_body_X_test, full_body_y_train, full_body_y_test, body_feature_names, classes = load_dataset('processed', 'skeleton')
full_body_X = full_body_X_train.copy()
full_body_y = full_body_y_train.copy()

print(full_body_X_train.shape, full_body_y_train.shape)
print(full_body_X_test.shape, full_body_y_test.shape)

n_length, body_features, body_outputs = full_body_X_train.shape[2], full_body_X_train.shape[-1], full_body_y_test.shape[1]
# Out:
# (525, 1, 350, 38) (525, 4)
# (90, 1, 350, 38) (90, 4)

# %% [markdown]
# ### Apply Data Augmentation

# %%
def jitter(x, sigma=0.03):
    # https://arxiv.org/pdf/1706.00527.pdf
    return x + np.random.normal(loc=0., scale=sigma, size=x.shape)

# %%
jitter_X = jitter(full_body_X, sigma=0.03)

# %%
def rotation(x):
    flip = np.random.choice([-1, 1], size=(x.shape[0],x.shape[2]))
    rotate_axis = np.arange(x.shape[2])
    np.random.shuffle(rotate_axis)    
    return flip[:,np.newaxis,:] * x[:,:,rotate_axis]

# %%
reshaped_X = full_body_X.reshape((full_body_X.shape[0], full_body_X.shape[2], full_body_X.shape[-1]))
rotated_X = rotation(reshaped_X)
rotated_X = rotated_X.reshape((rotated_X.shape[0], 1, rotated_X.shape[1], rotated_X.shape[-1]))

# %%
augmented_X = np.concatenate((rotated_X, jitter_X), axis=0)
add_y = np.concatenate((full_body_y, full_body_y), axis=0)
full_X = np.concatenate((augmented_X, full_body_X), axis=0)
full_y = np.concatenate((add_y, full_body_y), axis=0)
full_X.shape
# Out:
# (1575, 1, 350, 38)

# %%
body_feature_names
# Out:
# ['head_x',
#  'head_y',
#  'head_score',
#  'left_shoulder_x',
#  'left_shoulder_y',
#  'left_shoulder_score',
#  'left_elbow_x',
#  'left_elbow_y',
#  'left_elbow_score',
#  'right_shoulder_x',
#  'right_shoulder_y',
#  'right_shoulder_score',
#  'right_elbow_x',
#  'right_elbow_y',
#  'right_elbow_score',
#  'left_hand_x',
#  'left_hand_y',
#  'left_hand_score',
#  'right_hand_x',
#  'right_hand_y',
#  'right_hand_score',
#  'left_hip_x',
#  'left_hip_y',
#  'left_hip_score',
#  'right_hip_x',
#  'right_hip_y',
#  'right_hip_score',
#  'left_knee_x',
#  'left_knee_y',
#  'left_knee_score',
#  'right_knee_x',
#  'right_knee_y',
#  'right_knee_score',
#  'left_foot_x',
#  'left_foot_y',
#  'left_foot_score',
#  'right_foot_x',
#  'right_foot_y']

# %% [markdown]
# The train dataset is imbalanced

# %%
umild, lmoderate, lmild, umoderate = np.sum(full_y, axis=0)
total = umild + lmoderate + lmild + umoderate

print(classes[0], ':', umild, '({:.1f}% of total)'.format(umild / total * 100))
print(classes[2], ':', lmild, '({:.1f}% of total)'.format(lmild / total * 100))
print(classes[1], ':', lmoderate, '({:.1f}% of total)'.format(lmoderate / total * 100))
print(classes[3], ':', umoderate, '({:.1f}% of total)'.format(umoderate / total * 100))
# Out:
# UpperBody Mild : 831 (52.8% of total)
# LowerBody Mild : 591 (37.5% of total)
# LowerBody Moderate : 147 (9.3% of total)
# UpperBody Moderate : 6 (0.4% of total)

# %%
weight_for_0 = (1 / umild) * (total / 2.0)
weight_for_1 = (1 / lmoderate) * (total / 2.0)
weight_for_2 = (1 / lmild) * (total / 2.0)
weight_for_3 = (1 / umoderate) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2, 3: weight_for_3}

print('Weight for Upper Body Pain Mild Level: {:.2f}'.format(weight_for_0))
print('Weight for Upper Body Pain Moderate Level: {:.2f}'.format(weight_for_3))
print('Weight for Lower Body Pain Mild Level: {:.2f}'.format(weight_for_2))
print('Weight for Lower Body Pain Moderate Level: {:.2f}'.format(weight_for_1))
# Out:
# Weight for Upper Body Pain Mild Level: 0.95
# Weight for Upper Body Pain Moderate Level: 131.25
# Weight for Lower Body Pain Mild Level: 1.33
# Weight for Lower Body Pain Moderate Level: 5.36

# %% [markdown]
# ### 1.1 Body modality (skeleton) models

# %% [markdown]
# #### Train BiLSTM

# %%
for train_index, val_index in kf.split(full_X):
    X_train, X_val = full_X[train_index], full_X[val_index]
    y_train, y_val = full_y[train_index], full_y[val_index]
    body_biConvLSTM = build_biConvLSTM(body_features, n_length, body_outputs)
    history = train(body_biConvLSTM, X_train, y_train, X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 33/33 - 54s - loss: 15.6994 - accuracy: 0.2181 - auc: 0.5433 - precision: 0.3648 - recall: 0.1619 - f1_score: 0.1730 - val_loss: 1.3925 - val_accuracy: 0.0190 - val_auc: 0.3598 - val_precision: 0.5625 - val_recall: 0.0171 - val_f1_score: 0.0250 - 54s/epoch - 2s/step
# Epoch 2/50
# 33/33 - 31s - loss: 7.9038 - accuracy: 0.0181 - auc: 0.3554 - precision: 0.5238 - recall: 0.0105 - f1_score: 0.0244 - val_loss: 1.3961 - val_accuracy: 0.0038 - val_auc: 0.3381 - val_precision: 0.5000 - val_recall: 0.0019 - val_f1_score: 0.0038 - 31s/epoch - 951ms/step
# Epoch 3/50
# 33/33 - 32s - loss: 3.0454 - accuracy: 0.0114 - auc: 0.3442 - precision: 0.7143 - recall: 0.0048 - f1_score: 0.0127 - val_loss: 1.3999 - val_accuracy: 0.0000e+00 - val_auc: 0.3333 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - 32s/epoch - 973ms/step
# Epoch 4/50
# 33/33 - 29s - loss: 3.0401 - accuracy: 0.0124 - auc: 0.3458 - precision: 0.8750 - recall: 0.0067 - f1_score: 0.0140 - val_loss: 1.3952 - val_accuracy: 0.0000e+00 - val_auc: 0.3333 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - 29s/epoch - 870ms/step
# Epoch 5/50
# 33/33 - 29s - loss: 3.0366 - accuracy: 0.0114 - auc: 0.3479 - precision: 1.0000 - recall: 0.0057 - f1_score: 0.0132 - val_loss: 1.3974 - val_accuracy: 0.0000e+00 - val_auc: 0.4448 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - 29s/epoch - 867ms/step
# Epoch 6/50
# 33/33 - 28s - loss: 3.0350 - accuracy: 0.0114 - auc: 0.4669 - precision: 1.0000 - recall: 0.0057 - f1_score: 0.0132 - val_loss: 1.3990 - val_accuracy: 0.0000e+00 - val_auc: 0.4448 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - 28s/epoch - 863ms/step
# Epoch 7/50
# 33/33 - 34s - loss: 3.0348 - accuracy: 0.0114 - auc: 0.4666 - precision: 1.0000 - recall: 0.0057 - f1_score: 0.0132 - val_loss: 1.4002 - val_accuracy: 0.0000e+00 - val_auc: 0.4448 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 - 34s/epoch - 1s/step
# Epoch 8/50
# 33/33 - 32s - loss: 3.0322 - accuracy: 0.0114 - auc: 0.4669 - precision: 1.0000 - recall: 0.0057 - f1_score: 0.0132 - val_loss: 1.4003 - val_accuracy: 0.0000e+00 - val_auc: 0.4448 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0000e+00 
# Epoch 1/50
# 33/33 - 47s - loss: 20.0507 - accuracy: 0.3457 - auc_2: 0.6214 - precision_2: 0.3468 - recall_2: 0.3019 - f1_score: 0.2350 - val_loss: 1.9618 - val_accuracy: 0.4438 - val_auc_2: 0.7127 - val_precision_2: 0.4358 - val_recall_2: 0.3619 - val_f1_score: 0.2335 - 47s/epoch - 1s/step
# Epoch 2/50
# 33/33 - 31s - loss: 2.5580 - accuracy: 0.3505 - auc_2: 0.6940 - precision_2: 0.4280 - recall_2: 0.2067 - f1_score: 0.2466 - val_loss: 2.0224 - val_accuracy: 0.1924 - val_auc_2: 0.5988 - val_precision_2: 0.3264 - val_recall_2: 0.0895 - val_f1_score: 0.1395 - 31s/epoch - 934ms/step
# Epoch 3/50
# 33/33 - 31s - loss: 1.9996 - accuracy: 0.2867 - auc_2: 0.6659 - precision_2: 0.5000 - recall_2: 0.1305 - f1_score: 0.2148 - val_loss: 1.8265 - val_accuracy: 0.2229 - val_auc_2: 0.6277 - val_precision_2: 0.3511 - val_recall_2: 0.0629 - val_f1_score: 0.1656 - 31s/epoch - 941ms/step
# Epoch 4/50
# 33/33 - 31s - loss: 1.4927 - accuracy: 0.3971 - auc_2: 0.7763 - precision_2: 0.7129 - recall_2: 0.2152 - f1_score: 0.2861 - val_loss: 1.7241 - val_accuracy: 0.3600 - val_auc_2: 0.7450 - val_precision_2: 0.4496 - val_recall_2: 0.1105 - val_f1_score: 0.2303 - 31s/epoch - 938ms/step
# Epoch 5/50
# 33/33 - 31s - loss: 1.4882 - accuracy: 0.4229 - auc_2: 0.7806 - precision_2: 0.7047 - recall_2: 0.2295 - f1_score: 0.3013 - val_loss: 1.8267 - val_accuracy: 0.4057 - val_auc_2: 0.7624 - val_precision_2: 0.4828 - val_recall_2: 0.1333 - val_f1_score: 0.2287 - 31s/epoch - 932ms/step
# Epoch 6/50
# 33/33 - 31s - loss: 1.3296 - accuracy: 0.4867 - auc_2: 0.8129 - precision_2: 0.7774 - recall_2: 0.2495 - f1_score: 0.3383 - val_loss: 2.1317 - val_accuracy: 0.4095 - val_auc_2: 0.7319 - val_precision_2: 0.4843 - val_recall_2: 0.1467 - val_f1_score: 0.2611 - 31s/epoch - 933ms/step
# Epoch 7/50
# 33/33 - 31s - loss: 1.2779 - accuracy: 0.4838 - auc_2: 0.8149 - precision_2: 0.6900 - recall_2: 0.3095 - f1_score: 0.3358 - val_loss: 2.1285 - val_accuracy: 0.3105 - val_auc_2: 0.7093 - val_precision_2: 0.4437 - val_recall_2: 0.1352 - val_f1_score: 0.2153 - 31s/epoch - 936ms/step
# Epoch 8/50
# 33/33 - 31s - loss: 1.3315 - accuracy: 0.4676 - auc_2: 0.8174 - precision_2: 0.6103 - recall_2: 0.3162 - f1_score: 0.3319 - val_loss: 2.2565 - val_accuracy: 0.2571 - val_auc_2: 0.6573 - val_precision_2: 0.3964 - val_recall_2: 0.1276 - val_f1_score: 0.1918 - 31s/epoch - 936ms/step
# Epoch 9/50
# 33/33 - 31s - loss: 1.2674 - accuracy: 0.4552 - auc_2: 0.8107 - precision_2: 0.8736 - recall_2: 0.3029 - f1_score: 0.3226 - val_loss: 2.1219 - val_accuracy: 0.3486 - val_auc_2: 0.7083 - val_precision_2: 0.4621 - val_recall_2: 0.1276 - val_f1_score: 0.2202 - 31s/epoch - 940ms/step
# Epoch 10/50
# 33/33 - 31s - loss: 1.1832 - accuracy: 0.4943 - auc_2: 0.8334 - precision_2: 0.8756 - recall_2: 0.3286 - f1_score: 0.3490 - val_loss: 2.0792 - val_accuracy: 0.3752 - val_auc_2: 0.7204 - val_precision_2: 0.3807 - val_recall_2: 0.1276 - val_f1_score: 0.2054 - 31s/epoch - 931ms/step
# Epoch 11/50
# 33/33 - 33s - loss: 1.1395 - accuracy: 0.5152 - auc_2: 0.8537 - precision_2: 0.9434 - recall_2: 0.3333 - f1_score: 0.3630 - val_loss: 2.2842 - val_accuracy: 0.3010 - val_auc_2: 0.6878 - val_precision_2: 0.4910 - val_recall_2: 0.1562 - val_f1_score: 0.2145 - 33s/epoch - 1s/step
# Epoch 12/50
# 33/33 - 33s - loss: 1.1245 - accuracy: 0.5114 - auc_2: 0.8556 - precision_2: 0.7544 - recall_2: 0.3686 - f1_score: 0.3624 - val_loss: 2.4858 - val_accuracy: 0.2286 - val_auc_2: 0.6491 - val_precision_2: 0.2983 - val_recall_2: 0.1676 - val_f1_score: 0.1734 - 33s/epoch - 996ms/step
# Epoch 13/50
# 33/33 - 30s - loss: 1.1452 - accuracy: 0.4686 - auc_2: 0.8338 - precision_2: 0.7273 - recall_2: 0.3733 - f1_score: 0.3418 - val_loss: 2.5267 - val_accuracy: 0.3143 - val_auc_2: 0.6852 - val_precision_2: 0.4494 - val_recall_2: 0.1352 - val_f1_score: 0.2266 - 30s/epoch - 907ms/step
# Epoch 14/50
# 33/33 - 33s - loss: 1.2519 - accuracy: 0.5152 - auc_2: 0.8524 - precision_2: 0.8430 - recall_2: 0.3324 - f1_score: 0.3591 - val_loss: 2.6821 - val_accuracy: 0.3543 - val_auc_2: 0.7168 - val_precision_2: 0.4506 - val_recall_2: 0.1390 - val_f1_score: 0.2206 - 33s/epoch - 1s/step

# %% [markdown]
# #### Train CNN+LSTM

# %%
for train_index, val_index in kf.split(full_X):
    X_train, X_val = full_X[train_index], full_X[val_index]
    y_train, y_val = full_y[train_index], full_y[val_index]
    body_cnn = build_CNN(body_features, n_length, body_outputs)
    history = train(body_cnn, X_train, y_train, X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 33/33 - 7s - loss: 3.1060 - accuracy: 0.4752 - auc_3: 0.6404 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - f1_score: 0.1673 - val_loss: 1.3696 - val_accuracy: 0.4914 - val_auc_3: 0.6089 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_f1_score: 0.1648 - 7s/epoch - 197ms/step
# Epoch 2/50
# 33/33 - 2s - loss: 3.0588 - accuracy: 0.4362 - auc_3: 0.5622 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - f1_score: 0.1665 - val_loss: 1.4053 - val_accuracy: 0.0000e+00 - val_auc_3: 0.4124 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+
- val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_f1_score: 0.1303 - 2s/epoch - 62ms/step
# Epoch 13/50
# 33/33 - 2s - loss: 1.6899 - accuracy: 0.3229 - auc_5: 0.6848 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - f1_score: 0.1816 - val_loss: 1.1758 - val_accuracy: 0.0838 - val_auc_5: 0.5029 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_f1_score: 0.0387 - 2s/epoch - 61ms/step
# Epoch 14/50
# 33/33 - 2s - loss: 1.6850 - accuracy: 0.0981 - auc_5: 0.5314 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - f1_score: 0.0447 - val_loss: 1.2032 - val_accuracy: 0.0838 - val_auc_5: 0.5029 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_f1_score: 0.0387 - 2s/epoch - 62ms/step

# %% [markdown]
# #### Train ConvLSTM

# %%
for train_index, val_index in kf.split(full_X):
    X_train, X_val = full_X[train_index], full_X[val_index]
    y_train, y_val = full_y[train_index], full_y[val_index]
    body_convLSTM = build_convLSTM(body_features, n_length, body_outputs)
    history = train(body_convLSTM, X_train, y_train, X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 33/33 - 9s - loss: 42.2528 - accuracy: 0.3171 - auc_6: 0.5868 - precision_6: 0.3361 - recall_6: 0.2714 - f1_score: 0.2363 - val_loss: 4.3471 - val_accuracy: 0.2705 - val_auc_6: 0.5795 - val_precision_6: 0.3425 - val_recall_6: 0.1657 - val_f1_score: 0.1839 - 9s/epoch - 272ms/step
# Epoch 2/50
# 33/33 - 5s - loss: 11.4950 - accuracy: 0.1733 - auc_6: 0.5446 - precision_6: 0.4261 - recall_6: 0.1429 - f1_score: 0.1644 - val_loss: 4.7994 - val_accuracy: 0.1276 - val_auc_6: 0.4868 - val_precision_6: 0.3065 - val_recall_6: 0.1086 - val_f1_score: 0.1197 - 5s/epoch - 162ms/step
# Epoch 3/50
# 33/33 - 5s - loss: 6.1209 - accuracy: 0.2514 - auc_6: 0.6044 - precision_6: 0.4648 - recall_6: 0.1695 - f1_score: 0.2207 - val_loss: 5.1011 - val_accuracy: 0.1390 - val_auc_6: 0.5042 - val_precision_6: 0.2967 - val_recall_6: 0.1029 - val_f1_score: 0.1226 - 5s/epoch - 160ms/step
# Epoch 4/50
# 33/33 - 5s - loss: 18.3323 - accuracy: 0.2048 - auc_6: 0.5730 - precision_6: 0.5276 - recall_6: 0.1819 - f1_score: 0.1983 - val_loss: 6.5225 - val_accuracy: 0.1181 - val_auc_6: 0.4576 - val_precision_6: 0.3085 - val_recall_6: 0.1105 - val_f1_score: 0.1245 - 5s/epoch - 149ms/step
# Epoch 5/50
# 33/33 - 5s - loss: 9.5546 - accuracy: 0.1514 - auc_6: 0.4871 - precision_6: 0.3994 - recall_6: 0.1324 - f1_score: 0.1657 - val_loss: 6.2949 - val_accuracy: 0.1162 - val_auc_6: 0.4849 - val_precision_6: 0.3207 - val_recall_6: 0.1124 - val_f1_score: 0.1029 - 5s/epoch - 147ms/step
# Epoch 6/50
# 33/33 - 5s - loss: 1.6830 - accuracy: 0.5257 - auc_8: 0.7899 - precision_8: 0.6888 - recall_8: 0.2171 - f1_score: 0.3543 - val_loss: 3.0189 - val_accuracy: 0.3581 - val_auc_8: 0.7018 - val_precision_8: 0.3618 - val_recall_8: 0.1048 - val_f1_score: 0.1796 - 5s/epoch - 156ms/step
# Epoch 19/50
# 33/33 - 7s - loss: 2.7060 - accuracy: 0.4476 - auc_8: 0.7814 - precision_8: 0.6327 - recall_8: 0.2067 - f1_score: 0.3062 - val_loss: 2.6830 - val_accuracy: 0.4381 - val_auc_8: 0.7178 - val_precision_8: 0.3613 - val_recall_8: 0.1067 - val_f1_score: 0.2350 - 7s/epoch - 200ms/step
# Epoch 20/50
# 33/33 - 6s - loss: 1.9274 - accuracy: 0.4219 - auc_8: 0.7695 - precision_8: 0.6374 - recall_8: 0.2076 - f1_score: 0.2871 - val_loss: 3.2066 - val_accuracy: 0.4038 - val_auc_8: 0.7131 - val_precision_8: 0.3831 - val_recall_8: 0.1124 - val_f1_score: 0.2544 - 6s/epoch - 190ms/step
# Epoch 21/50
# 33/33 - 7s - loss: 2.3058 - accuracy: 0.3752 - auc_8: 0.7100 - precision_8: 0.6029 - recall_8: 0.1952 - f1_score: 0.2733 - val_loss: 2.3700 - val_accuracy: 0.3010 - val_auc_8: 0.6248 - val_precision_8: 0.3087 - val_recall_8: 0.0876 - val_f1_score: 0.1913 - 7s/epoch - 202ms/step
# Epoch 22/50
# 33/33 - 6s - loss: 2.4519 - accuracy: 0.3800 - auc_8: 0.7302 - precision_8: 0.4443 - recall_8: 0.2467 - f1_score: 0.2716 - val_loss: 2.3459 - val_accuracy: 0.1619 - val_auc_8: 0.5650 - val_precision_8: 0.3205 - val_recall_8: 0.0952 - val_f1_score: 0.1258 - 6s/epoch - 190ms/step

# %% [markdown]
# #### Train RCNN

# %%
for train_index, val_index in kf.split(full_X):
    X_train, X_val = full_X[train_index], full_X[val_index]
    y_train, y_val = full_y[train_index], full_y[val_index]
    body_rcnn = build_RCNN(body_features, n_length, body_outputs)
    history = train(body_rcnn, X_train, y_train, X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 33/33 - 4s - loss: 66.0321 - accuracy: 0.2657 - auc_9: 0.5196 - precision_9: 0.2672 - recall_9: 0.2629 - f1_score: 0.1970 - val_loss: 61.1706 - val_accuracy: 0.3390 - val_auc_9: 0.5528 - val_precision_9: 0.3390 - val_recall_9: 0.3390 - val_f1_score: 0.1616 - 4s/epoch - 121ms/step
# Epoch 2/50
# 33/33 - 2s - loss: 42.0052 - accuracy: 0.3162 - auc_9: 0.5604 - precision_9: 0.3170 - recall_9: 0.3143 - f1_score: 0.2297 - val_loss: 29.7121 - val_accuracy: 0.3352 - val_auc_9: 0.5541 - val_precision_9: 0.3352 - val_recall_9: 0.3352 - val_f1_score: 0.1714 - 2s/epoch - 75ms/step
# Epoch 3/50
# 33/33 - 2s - loss: 101.3809 - accuracy: 0.2800 - auc_9: 0.5339 - precision_9: 0.2779 - recall_9: 0.2752 - f1_score: 0.2090 - val_loss: 40.9107 - val_accuracy: 0.4171 - val_auc_9: 0.6124 - val_precision_9: 0.4171 - val_recall_9: 0.4171 - val_f1_score: 0.2076 - 2s/epoch - 73ms/step
# Epoch 7/50
# 33/33 - 2s - loss: 5.3145 - accuracy: 0.3705 - auc_10: 0.6721 - precision_10: 0.3695 - recall_10: 0.3438 - f1_score: 0.2973 - val_loss: 2.7314 - val_accuracy: 0.4781 - val_auc_10: 0.7176 - val_precision_10: 0.4832 - val_recall_10: 0.4648 - val_f1_score: 0.2193 - 2s/epoch - 65ms/step
# Epoch 8/50
# 33/33 - 2s - loss: 3.2281 - accuracy: 0.3895 - auc_10: 0.6985 - precision_10: 0.3962 - recall_10: 0.3381 - f1_score: 0.3407 - val_loss: 1.7643 - val_accuracy: 0.3619 - val_auc_10: 0.7050 - val_precision_10: 0.3705 - val_recall_10: 0.2914 - val_f1_score: 0.2265 - 2s/epoch - 61ms/step
# Epoch 9/50
# 33/33 - 2s - loss: 6.6875 - accuracy: 0.3581 - auc_10: 0.6632 - precision_10: 0.3606 - recall_10: 0.2943 - f1_score: 0.2878 - val_loss: 12.2542 - val_accuracy: 0.2362 - val_auc_10: 0.4933 - val_precision_10: 0.2295 - val_recall_10: 0.2133 - val_f1_score: 0.1805 - 2s/epoch - 60ms/step
# Epoch 10/50
# 33/33 - 2s - loss: 13.4936 - accuracy: 0.3400 - auc_10: 0.6545 - precision_10: 0.3491 - recall_10: 0.3171 - f1_score: 0.2733 - val_loss: 44.0167 - val_accuracy: 0.3981 - val_auc_10: 0.6083 - val_precision_10: 0.3981 - val_recall_10: 0.3981 - val_f1_score: 0.2108 - 2s/epoch - 60ms/step
# Epoch 11/50
# 33/33 - 2s - loss: 26.0419 - accuracy: 0.3276 - auc_10: 0.5833 - precision_10: 0.3266 - recall_10: 0.3229 - f1_score: 0.2591 - val_loss: 9.8159 - val_accuracy: 0.5143 - val_auc_10: 0.6760 - val_precision_10: 0.5143 - val_recall_10: 0.5143 - val_f1_score: 0.2285 - 2s/epoch - 59ms/step
# Epoch 12/50
# 33/33 - 2s - loss: 24.8688 - accuracy: 0.3419 - auc_10: 0.6049 - precision_10: 0.3387 - recall_10: 0.3229 - f1_score: 0.2561 - val_loss: 4.5511 - val_accuracy: 0.4229 - val_auc_10: 0.7027 - val_precision_10: 0.4228 - val_recall_10: 0.4171 - val_f1_score: 0.2145 - 2s/epoch - 59ms/step
# Epoch 13/50
# 33/33 - 2s - loss: 4.8099 - accuracy: 0.3429 - auc_10: 0.6613 - precision_10: 0.3452 - recall_10: 0.3143 - f1_score: 0.3173 - val_loss: 3.0035 - val_accuracy: 0.3657 - val_auc_10: 0.7198 - val_precision_10: 0.3699 - val_recall_10: 0.3657 - val_f1_score: 0.1561 - 2s/epoch - 61ms/step
# Epoch 14/50
# 33/33 - 2s - loss: 27.8121 - accuracy: 0.3124 - auc_10: 0.5827 - precision_10: 0.3078 - recall_10: 0.2990 - f1_score: 0.2445 - val_loss: 16.2213 - val_accuracy: 0.3886 - val_auc_10: 0.6199 - val_precision_10: 0.3886 - val_recall_10: 0.3886 - val_f1_score: 0.2129 - 2s/epoch - 62ms/step
# Epoch 15/50
# 33/33 - 2s - loss: 49.8447 - accuracy: 0.2895 - auc_10: 0.5336 - precision_10: 0.2895 - recall_10: 0.2876 - f1_score: 0.2309 - val_loss: 22.3083 - val_accuracy: 0.4533 - val_auc_10: 0.6560 - val_precision_10: 0.4533 - val_recall_10: 0.4533 - val_f1_score: 0.2320 - 2s/epoch - 62ms/step
# Epoch 16/50
# 33/33 - 2s - loss: 33.8011 - accuracy: 0.3619 - auc_10: 0.5906 - precision_10: 0.3632 - recall_10: 0.3590 - f1_score: 0.2805 - val_loss: 23.0659 - val_accuracy: 0.3105 - val_auc_10: 0.5512 - val_precision_10: 0.3105 - val_recall_10: 0.3105 - val_f1_score: 0.1842 - 2s/epoch - 65ms/step
# Epoch 17/50
# 33/33 - 2s - loss: 26.4513 - accuracy: 0.3343 - auc_10: 0.5839 - precision_10: 0.3356 - recall_10: 0.3324 - f1_score: 0.2582 - val_loss: 25.1095 - val_accuracy: 0.2076 - val_auc_10: 0.4547 - val_precision_10: 0.2080 - val_recall_10: 0.2076 - val_f1_score: 0.1425 - 2s/epoch - 66ms/step
# Epoch 18/50
# 33/33 - 2s - loss: 18.5293 - accuracy: 0.3162 - auc_10: 0.6016 - precision_10: 0.3187 - recall_10: 0.3048 - f1_score: 0.2519 - val_loss: 17.1400 - val_accuracy: 0.1429 - val_auc_10: 0.4555 - val_precision_10: 0.1417 - val_recall_10: 0.1390 - val_f1_score: 0.1198 - 2s/epoch - 68ms/step
# Epoch 1/50
# 33/33 - 4s - loss: 19.1691 - accuracy: 0.3352 - auc_11: 0.6013 - precision_11: 0.3356 - recall_11: 0.3248 - f1_score: 0.2330 - val_loss: 28.1465 - val_accuracy: 0.1371 - val_auc_11: 0.4245 - val_precision_11: 0.1358 - val_recall_11: 0.1352 - val_f1_score: 0.1013 - 4s/epoch - 133ms/step
# Epoch 2/50
# 33/33 - 2s - loss: 6.1017 - accuracy: 0.3305 - auc_11: 0.6457 - precision_11: 0.3313 - recall_11: 0.3114 - f1_score: 0.2296 - val_loss: 4.2708 - val_accuracy: 0.4590 - val_auc_11: 0.7349 - val_precision_11: 0.4579 - val_recall_11: 0.4552 - val_f1_score: 0.1887 - 2s/epoch - 75ms/step
# Epoch 3/50
# 33/33 - 3s - loss: 3.5880 - accuracy: 0.3171 - auc_11: 0.6513 - precision_11: 0.3266 - recall_11: 0.2781 - f1_score: 0.2252 - val_loss: 3.8407 - val_accuracy: 0.1657 - val_auc_11: 0.6034 - val_precision_11: 0.1648 - val_recall_11: 0.1638 - val_f1_score: 0.1265 - 3s/epoch - 78ms/step
# Epoch 4/50
# 33/33 - 3s - loss: 3.6010 - accuracy: 0.3476 - auc_11: 0.6828 - precision_11: 0.3474 - recall_11: 0.2819 - f1_score: 0.2432 - val_loss: 2.9851 - val_accuracy: 0.2933 - val_auc_11: 0.6161 - val_precision_11: 0.2455 - val_recall_11: 0.1543 - val_f1_score: 0.1704 - 3s/epoch - 80ms/step
# Epoch 5/50
# 33/33 - 3s - loss: 3.6903 - accuracy: 0.3343 - auc_11: 0.6543 - precision_11: 0.3314 - recall_11: 0.2724 - f1_score: 0.2364 - val_loss: 4.3291 - val_accuracy: 0.4762 - val_auc_11: 0.7647 - val_precision_11: 0.4742 - val_recall_11: 0.4724 - val_f1_score: 0.2453 - 3s/epoch - 80ms/step
# Epoch 6/50
# 33/33 - 2s - loss: 4.7333 - accuracy: 0.3533 - auc_11: 0.6592 - precision_11: 0.3622 - recall_11: 0.3143 - f1_score: 0.2445 - val_loss: 3.4165 - val_accuracy: 0.3581 - val_auc_11: 0.7310 - val_precision_11: 0.3581 - val_recall_11: 0.3581 - val_f1_score: 0.1439 - 2s/epoch - 63ms/step
# Epoch 7/50
# 33/33 - 2s - loss: 3.9622 - accuracy: 0.3829 - auc_11: 0.6838 - precision_11: 0.3861 - recall_11: 0.3648 - f1_score: 0.2661 - val_loss: 7.1227 - val_accuracy: 0.1676 - val_auc_11: 0.4749 - val_precision_11: 0.1648 - val_recall_11: 0.1638 - val_f1_score: 0.1088 - 2s/epoch - 68ms/step
# Epoch 8/50
# 33/33 - 2s - loss: 3.3806 - accuracy: 0.3505 - auc_11: 0.6814 - precision_11: 0.3575 - recall_11: 0.3057 - f1_score: 0.2470 - val_loss: 2.3628 - val_accuracy: 0.4800 - val_auc_11: 0.7671 - val_precision_11: 0.4829 - val_recall_11: 0.4305 - val_f1_score: 0.2339 - 2s/epoch - 62ms/step
# Epoch 9/50
# 33/33 - 2s - loss: 2.5221 - accuracy: 0.3857 - auc_11: 0.7105 - precision_11: 0.3919 - recall_11: 0.3143 - f1_score: 0.2724 - val_loss: 2.7517 - val_accuracy: 0.2857 - val_auc_11: 0.6274 - val_precision_11: 0.2832 - val_recall_11: 0.2438 - val_f1_score: 0.2088 - 2s/epoch - 60ms/step
# Epoch 10/50
# 33/33 - 2s - loss: 2.3741 - accuracy: 0.3943 - auc_11: 0.7204 - precision_11: 0.4091 - recall_11: 0.3171 - f1_score: 0.2822 - val_loss: 3.3173 - val_accuracy: 0.2152 - val_auc_11: 0.5729 - val_precision_11: 0.2111 - val_recall_11: 0.1962 - val_f1_score: 0.1608 - 2s/epoch - 65ms/step
# Epoch 11/50
# 33/33 - 2s - loss: 2.2908 - accuracy: 0.3886 - auc_11: 0.7249 - precision_11: 0.3931 - recall_11: 0.3029 - f1_score: 0.2817 - val_loss: 3.2098 - val_accuracy: 0.1905 - val_auc_11: 0.6018 - val_precision_11: 0.1827 - val_recall_11: 0.1733 - val_f1_score: 0.1460 - 2s/epoch - 58ms/step
# Epoch 12/50
# 33/33 - 2s - loss: 2.2008 - accuracy: 0.3971 - auc_11: 0.7323 - precision_11: 0.4124 - recall_11: 0.2914 - f1_score: 0.2842 - val_loss: 2.6778 - val_accuracy: 0.3752 - val_auc_11: 0.6614 - val_precision_11: 0.3451 - val_recall_11: 0.2229 - val_f1_score: 0.2682 - 2s/epoch - 58ms/step
# Epoch 13/50
# 33/33 - 3s - loss: 2.0468 - accuracy: 0.4010 - auc_11: 0.7438 - precision_11: 0.4172 - recall_11: 0.3333 - f1_score: 0.2890 - val_loss: 2.2932 - val_accuracy: 0.3429 - val_auc_11: 0.6648 - val_precision_11: 0.3678 - val_recall_11: 0.3048 - val_f1_score: 0.2155 - 3s/epoch - 84ms/step
# Epoch 14/50
# 33/33 - 2s - loss: 1.9939 - accuracy: 0.3971 - auc_11: 0.7361 - precision_11: 0.4082 - recall_11: 0.3029 - f1_score: 0.2817 - val_loss: 2.3056 - val_accuracy: 0.2762 - val_auc_11: 0.6213 - val_precision_11: 0.2868 - val_recall_11: 0.1410 - val_f1_score: 0.2048 - 2s/epoch - 65ms/step
# Epoch 15/50
# 33/33 - 2s - loss: 1.7695 - accuracy: 0.4324 - auc_11: 0.7562 - precision_11: 0.4702 - recall_11: 0.3152 - f1_score: 0.3081 - val_loss: 1.8313 - val_accuracy: 0.4476 - val_auc_11: 0.7365 - val_precision_11: 0.4534 - val_recall_11: 0.2686 - val_f1_score: 0.2860 - 2s/epoch - 60ms/step
# Epoch 16/50
# 33/33 - 2s - loss: 1.7550 - accuracy: 0.4362 - auc_11: 0.7604 - precision_11: 0.4618 - recall_11: 0.3400 - f1_score: 0.3149 - val_loss: 1.8916 - val_accuracy: 0.4610 - val_auc_11: 0.7556 - val_precision_11: 0.5193 - val_recall_11: 0.2819 - val_f1_score: 0.2665 - 2s/epoch - 61ms/step
# Epoch 17/50
# 33/33 - 2s - loss: 1.7403 - accuracy: 0.4457 - auc_11: 0.7717 - precision_11: 0.4723 - recall_11: 0.3657 - f1_score: 0.3235 - val_loss: 1.7826 - val_accuracy: 0.3524 - val_auc_11: 0.6848 - val_precision_11: 0.3709 - val_recall_11: 0.2381 - val_f1_score: 0.2483 - 2s/epoch - 58ms/step
# Epoch 18/50
# 33/33 - 2s - loss: 1.6853 - accuracy: 0.4286 - auc_11: 0.7653 - precision_11: 0.4667 - recall_11: 0.3333 - f1_score: 0.3099 - val_loss: 1.6766 - val_accuracy: 0.4457 - val_auc_11: 0.7427 - val_precision_11: 0.4134 - val_recall_11: 0.2000 - val_f1_score: 0.2857 - 2s/epoch - 62ms/step
# Epoch 19/50
# 33/33 - 3s - loss: 1.6020 - accuracy: 0.4648 - auc_11: 0.7877 - precision_11: 0.5154 - recall_11: 0.3505 - f1_score: 0.3395 - val_loss: 1.4995 - val_accuracy: 0.4057 - val_auc_11: 0.7245 - val_precision_11: 0.4059 - val_recall_11: 0.2343 - val_f1_score: 0.2703 - 3s/epoch - 78ms/step
# Epoch 20/50
# 33/33 - 2s - loss: 2.0150 - accuracy: 0.4486 - auc_11: 0.7738 - precision_11: 0.4622 - recall_11: 0.3724 - f1_score: 0.3265 - val_loss: 3.7797 - val_accuracy: 0.3067 - val_auc_11: 0.6345 - val_precision_11: 0.2981 - val_recall_11: 0.2629 - val_f1_score: 0.2282 - 2s/epoch - 65ms/step
# Epoch 21/50
# 33/33 - 2s - loss: 2.7882 - accuracy: 0.4248 - auc_11: 0.7234 - precision_11: 0.4310 - recall_11: 0.3924 - f1_score: 0.3081 - val_loss: 3.6360 - val_accuracy: 0.4000 - val_auc_11: 0.7197 - val_precision_11: 0.4043 - val_recall_11: 0.3981 - val_f1_score: 0.2256 - 2s/epoch - 64ms/step
# Epoch 22/50
# 33/33 - 2s - loss: 2.9323 - accuracy: 0.4286 - auc_11: 0.7272 - precision_11: 0.4296 - recall_11: 0.3924 - f1_score: 0.3081 - val_loss: 2.6395 - val_accuracy: 0.4990 - val_auc_11: 0.7618 - val_precision_11: 0.5195 - val_recall_11: 0.4305 - val_f1_score: 0.3102 - 2s/epoch - 61ms/step
# Epoch 23/50
# 33/33 - 2s - loss: 3.2292 - accuracy: 0.4248 - auc_11: 0.7385 - precision_11: 0.4467 - recall_11: 0.4029 - f1_score: 0.3009 - val_loss: 4.1651 - val_accuracy: 0.3867 - val_auc_11: 0.6856 - val_precision_11: 0.3951 - val_recall_11: 0.3410 - val_f1_score: 0.2469 - 2s/epoch - 70ms/step
# Epoch 24/50
# 33/33 - 2s - loss: 3.9285 - accuracy: 0.4057 - auc_11: 0.7110 - precision_11: 0.4132 - recall_11: 0.3810 - f1_score: 0.2891 - val_loss: 4.2383 - val_accuracy: 0.3943 - val_auc_11: 0.6825 - val_precision_11: 0.3937 - val_recall_11: 0.3810 - val_f1_score: 0.2149 - 2s/epoch - 67ms/step
# Epoch 25/50
# 33/33 - 2s - loss: 2.8726 - accuracy: 0.3781 - auc_11: 0.7093 - precision_11: 0.3872 - recall_11: 0.3171 - f1_score: 0.2690 - val_loss: 2.8503 - val_accuracy: 0.4876 - val_auc_11: 0.7132 - val_precision_11: 0.4866 - val_recall_11: 0.4857 - val_f1_score: 0.2147 - 2s/epoch - 59ms/step
# Epoch 26/50
# 33/33 - 2s - loss: 1.9737 - accuracy: 0.4495 - auc_11: 0.7807 - precision_11: 0.4763 - recall_11: 0.4019 - f1_score: 0.3214 - val_loss: 2.7374 - val_accuracy: 0.3429 - val_auc_11: 0.6825 - val_precision_11: 0.3471 - val_recall_11: 0.3371 - val_f1_score: 0.1819 - 2s/epoch - 58ms/step
# Epoch 27/50
# 33/33 - 2s - loss: 1.8137 - accuracy: 0.4543 - auc_11: 0.7791 - precision_11: 0.4786 - recall_11: 0.3933 - f1_score: 0.3273 - val_loss: 2.0854 - val_accuracy: 0.4648 - val_auc_11: 0.7323 - val_precision_11: 0.4489 - val_recall_11: 0.3010 - val_f1_score: 0.2986 - 2s/epoch - 57ms/step
# Epoch 28/50
# 33/33 - 2s - loss: 1.4841 - accuracy: 0.4752 - auc_11: 0.8000 - precision_11: 0.5269 - recall_11: 0.3733 - f1_score: 0.3448 - val_loss: 1.7727 - val_accuracy: 0.4038 - val_auc_11: 0.7186 - val_precision_11: 0.3846 - val_recall_11: 0.2190 - val_f1_score: 0.2798 - 2s/epoch - 58ms/step
# Epoch 29/50
# 33/33 - 2s - loss: 1.3815 - accuracy: 0.5048 - auc_11: 0.8175 - precision_11: 0.5493 - recall_11: 0.3981 - f1_score: 0.3724 - val_loss: 2.2020 - val_accuracy: 0.2514 - val_auc_11: 0.6329 - val_precision_11: 0.2319 - val_recall_11: 0.1771 - val_f1_score: 0.1906 - 2s/epoch - 59ms/step

# %% [markdown]
# ### 1.2 Face modality (Action units)

# %%
face_X_train, face_X_test, face_y_train, face_y_test, face_feature_names, c = load_dataset('processed', 'AUs')
face_X = face_X_train.copy()
face_y = face_y_train.copy()

print(face_X_train.shape, face_y_train.shape)
print(face_X_test.shape, face_y_test.shape)

n_length, face_features, face_outputs = face_X_train.shape[2], face_X_train.shape[-1], face_y_train.shape[1]
# Out:
# (509, 1, 350, 10) (509, 4)
# (88, 1, 350, 10) (88, 4)

# %%
face_feature_names
# Out:
# ['confidence',
#  'AU04_r',
#  'AU06_r',
#  'AU07_r',
#  'AU09_r',
#  'AU10_r',
#  'AU04_c',
#  'AU06_c',
#  'AU07_c',
#  'AU09_c']

# %%
jitter_X = jitter(face_X, sigma=0.03)

# %%
reshaped_X = face_X.reshape((face_X.shape[0], face_X.shape[2], face_X.shape[-1]))
rotated_X = rotation(reshaped_X)
rotated_X = rotated_X.reshape((rotated_X.shape[0], 1, rotated_X.shape[1], rotated_X.shape[-1]))

# %%
augmented_X = np.concatenate((rotated_X, jitter_X), axis=0)
add_y = np.concatenate((face_y, face_y), axis=0)
full_X = np.concatenate((augmented_X, face_X), axis=0)
full_y = np.concatenate((add_y, face_y), axis=0)
full_X.shape
# Out:
# (1527, 1, 350, 10)

# %%
umild, lmoderate, lmild, umoderate = np.sum(full_y, axis=0)
total = umild + lmoderate + lmild + umoderate

weight_for_0 = (1 / umild) * (total / 2.0)
weight_for_1 = (1 / lmoderate) * (total / 2.0)
weight_for_2 = (1 / lmild) * (total / 2.0)
weight_for_3 = (1 / umoderate) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2, 3: weight_for_3}

print('Weight for Upper Body Pain Mild Level: {:.2f}'.format(weight_for_0))
print('Weight for Upper Body Pain Moderate Level: {:.2f}'.format(weight_for_3))
print('Weight for Lower Body Pain Mild Level: {:.2f}'.format(weight_for_2))
print('Weight for Lower Body Pain Moderate Level: {:.2f}'.format(weight_for_1))
# Out:
# Weight for Upper Body Pain Mild Level: 0.95
# Weight for Upper Body Pain Moderate Level: 127.25
# Weight for Lower Body Pain Mild Level: 1.33
# Weight for Lower Body Pain Moderate Level: 5.30

# %% [markdown]
# #### Train BiLSTM

# %%
for train_index, val_index in kf.split(full_X):
    X_train, X_val = full_X[train_index], full_X[val_index]
    y_train, y_val = full_y[train_index], full_y[val_index]
    face_biConvLSTM = build_biConvLSTM(face_features, n_length, face_outputs)
    history = train(face_biConvLSTM, X_train, y_train, X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 32/32 - 46s - loss: 2.9662 - accuracy: 0.4676 - auc_12: 0.7153 - precision_12: 0.5357 - recall_12: 0.0147 - f1_score: 0.2456 - val_loss: 1.1851 - val_accuracy: 0.5305 - val_auc_12: 0.7446 - val_precision_12: 0.5469 - val_recall_12: 0.0688 - val_f1_score: 0.1733 - 46s/epoch - 1s/step
# 32/32 - 30s - loss: 1.9224 - accuracy: 0.4882 - auc_14: 0.7969 - precision_14: 0.6040 - recall_14: 0.2367 - f1_score: 0.3407 - val_loss: 1.4920 - val_accuracy: 0.4067 - val_auc_14: 0.7038 - val_precision_14: 0.4309 - val_recall_14: 0.1532 - val_f1_score: 0.2572 - 30s/epoch - 932ms/step
# Epoch 12/50
# 32/32 - 30s - loss: 1.9100 - accuracy: 0.4990 - auc_14: 0.7711 - precision_14: 0.6659 - recall_14: 0.2721 - f1_score: 0.3405 - val_loss: 1.6286 - val_accuracy: 0.4401 - val_auc_14: 0.7293 - val_precision_14: 0.5621 - val_recall_14: 0.1866 - val_f1_score: 0.2820 - 30s/epoch - 935ms/step
# Epoch 13/50
# 32/32 - 30s - loss: 1.8919 - accuracy: 0.5236 - auc_14: 0.7899 - precision_14: 0.6780 - recall_14: 0.2750 - f1_score: 0.3645 - val_loss: 1.2687 - val_accuracy: 0.4401 - val_auc_14: 0.7476 - val_precision_14: 0.5102 - val_recall_14: 0.1965 - val_f1_score: 0.2901 - 30s/epoch - 935ms/step
# Epoch 14/50
# 32/32 - 30s - loss: 1.8751 - accuracy: 0.5128 - auc_14: 0.7795 - precision_14: 0.6421 - recall_14: 0.2819 - f1_score: 0.3607 - val_loss: 1.2890 - val_accuracy: 0.4401 - val_auc_14: 0.7241 - val_precision_14: 0.4922 - val_recall_14: 0.1866 - val_f1_score: 0.2811 - 30s/epoch - 937ms/step
# Epoch 15/50
# 32/32 - 30s - loss: 1.8393 - accuracy: 0.4607 - auc_14: 0.7691 - precision_14: 0.6875 - recall_14: 0.2917 - f1_score: 0.3525 - val_loss: 1.3609 - val_accuracy: 0.3851 - val_auc_14: 0.7458 - val_precision_14: 0.6092 - val_recall_14: 0.2083 - val_f1_score: 0.3040 - 30s/epoch - 934ms/step
# Epoch 16/50
# 32/32 - 30s - loss: 2.3178 - accuracy: 0.5049 - auc_14: 0.8193 - precision_14: 0.7181 - recall_14: 0.3202 - f1_score: 0.3578 - val_loss: 1.7061 - val_accuracy: 0.3360 - val_auc_14: 0.7339 - val_precision_14: 0.5694 - val_recall_14: 0.2338 - val_f1_score: 0.2192 - 30s/epoch - 937ms/step
# Epoch 17/50
# 32/32 - 30s - loss: 1.9079 - accuracy: 0.5167 - auc_14: 0.8160 - precision_14: 0.7637 - recall_14: 0.3143 - f1_score: 0.3661 - val_loss: 1.6260 - val_accuracy: 0.4872 - val_auc_14: 0.7851 - val_precision_14: 0.6221 - val_recall_14: 0.2652 - val_f1_score: 0.3201 - 30s/epoch - 939ms/step

# %% [markdown]
# #### Train CNN+LSTM

# %%
for train_index, val_index in kf.split(full_X):
    X_train, X_val = full_X[train_index], full_X[val_index]
    y_train, y_val = full_y[train_index], full_y[val_index]
    face_cnn = build_CNN(face_features, n_length, face_outputs)
    history = train(face_cnn, X_train, y_train, X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 32/32 - 2s - loss: 2.3657 - accuracy: 0.3644 - auc_17: 0.6979 - precision_17: 0.7188 - recall_17: 0.0226 - f1_score: 0.2468 - val_loss: 1.1705 - val_accuracy: 0.4872 - val_auc_17: 0.7977 - val_precision_17: 0.5000 - val_recall_17: 0.0039 - val_f1_score: 0.2057 - 2s/epoch - 64ms/step
# Epoch 18/50
# 32/32 - 2s - loss: 2.4938 - accuracy: 0.3448 - auc_17: 0.6973 - precision_17: 0.5000 - recall_17: 0.0049 - f1_score: 0.2268 - val_loss: 1.2369 - val_accuracy: 0.3615 - val_auc_17: 0.7539 - val_precision_17: 0.5000 - val_recall_17: 0.0059 - val_f1_score: 0.1606 - 2s/epoch - 64ms/step
# Epoch 19/50
# 32/32 - 2s - loss: 2.3784 - accuracy: 0.3291 - auc_17: 0.7177 - precision_17: 0.7778 - recall_17: 0.0069 - f1_score: 0.1768 - val_loss: 1.2036 - val_accuracy: 0.3477 - val_auc_17: 0.7507 - val_precision_17: 0.6000 - val_recall_17: 0.0059 - val_f1_score: 0.1464 - 2s/epoch - 65ms/step
# Epoch 20/50
# 32/32 - 2s - loss: 2.4374 - accuracy: 0.2967 - auc_17: 0.7162 - precision_17: 0.6667 - recall_17: 0.0098 - f1_score: 0.1712 - val_loss: 1.3023 - val_accuracy: 0.1473 - val_auc_17: 0.6055 - val_precision_17: 0.4000 - val_recall_17: 0.0039 - val_f1_score: 0.0926 - 2s/epoch - 62ms/step
# Epoch 21/50
# 32/32 - 2s - loss: 2.4011 - accuracy: 0.3409 - auc_17: 0.7415 - precision_17: 0.7500 - recall_17: 0.0059 - f1_score: 0.2397 - val_loss: 1.3215 - val_accuracy: 0.1434 - val_auc_17: 0.5718 - val_precision_17: 0.5000 - val_recall_17: 0.0039 - val_f1_score: 0.1020 - 2s/epoch - 63ms/step

# %% [markdown]
# #### Train ConvLSTM

# %%
for train_index, val_index in kf.split(full_X):
    X_train, X_val = full_X[train_index], full_X[val_index]
    y_train, y_val = full_y[train_index], full_y[val_index]
    face_convLSTM = build_convLSTM(face_features, n_length, face_outputs)
    history = train(face_convLSTM, X_train, y_train, X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 32/32 - 9s - loss: 2.8633 - accuracy: 0.3802 - auc_18: 0.7158 - precision_18: 0.6500 - recall_18: 0.0383 - f1_score: 0.2401 - val_loss: 1.2811 - val_accuracy: 0.1061 - val_auc_18: 0.6046 - val_precision_18: 0.0000e+00 - val_recall_18: 0.0000e+00 - val_f1_score: 0.0539 - 9s/epoch - 294ms/step
# Epoch 2/50
# 32/32 - 5s - loss: 2.7363 - accuracy: 0.3566 - auc_18: 0.7098 - precision_18: 0.6400 - recall_18: 0.0472 - f1_score: 0.2259 - val_loss: 1.2314 - val_accuracy: 0.1316 - val_auc_18: 0.6342 - val_precision_18: 0.0435 - val_recall_18: 0.0020 - val_f1_score: 0.0778 - 5s/epoch - 152ms/step
# Epoch 3/50
# 32/32 - 5s - loss: 2.1165 - accuracy: 0.3104 - auc_20: 0.7091 - precision_20: 0.5897 - recall_20: 0.1356 - f1_score: 0.2293 - val_loss: 1.2626 - val_accuracy: 0.3615 - val_auc_20: 0.7122 - val_precision_20: 0.4000 - val_recall_20: 0.1139 - val_f1_score: 0.1895 - 5s/epoch - 154ms/step
# Epoch 7/50
# 32/32 - 5s - loss: 2.0625 - accuracy: 0.3644 - auc_20: 0.7289 - precision_20: 0.5690 - recall_20: 0.1621 - f1_score: 0.2659 - val_loss: 1.2625 - val_accuracy: 0.3124 - val_auc_20: 0.7024 - val_precision_20: 0.5600 - val_recall_20: 0.1375 - val_f1_score: 0.2366 - 5s/epoch - 152ms/step
# Epoch 8/50
# 32/32 - 5s - loss: 1.9684 - accuracy: 0.4224 - auc_20: 0.7667 - precision_20: 0.6452 - recall_20: 0.2161 - f1_score: 0.3006 - val_loss: 1.3670 - val_accuracy: 0.3792 - val_auc_20: 0.7048 - val_precision_20: 0.4545 - val_recall_20: 0.1670 - val_f1_score: 0.2228 - 5s/epoch - 154ms/step
# Epoch 9/50
# 32/32 - 5s - loss: 1.8826 - accuracy: 0.5138 - auc_20: 0.7911 - precision_20: 0.6945 - recall_20: 0.2613 - f1_score: 0.3576 - val_loss: 1.3640 - val_accuracy: 0.4578 - val_auc_20: 0.7384 - val_precision_20: 0.5678 - val_recall_20: 0.2220 - val_f1_score: 0.3012 - 5s/epoch - 154ms/step
# Epoch 10/50
# 32/32 - 5s - loss: 1.9163 - accuracy: 0.4912 - auc_20: 0.7885 - precision_20: 0.6334 - recall_20: 0.2868 - f1_score: 0.3407 - val_loss: 1.4105 - val_accuracy: 0.3733 - val_auc_20: 0.6643 - val_precision_20: 0.3778 - val_recall_20: 0.1670 - val_f1_score: 0.2101 - 5s/epoch - 157ms/step
# Epoch 11/50
# 32/32 - 5s - loss: 1.8489 - accuracy: 0.4558 - auc_20: 0.7759 - precision_20: 0.7075 - recall_20: 0.2780 - f1_score: 0.3280 - val_loss: 1.3238 - val_accuracy: 0.5029 - val_auc_20: 0.7829 - val_precision_20: 0.6526 - val_recall_20: 0.2731 - val_f1_score: 0.3263 - 5s/epoch - 153ms/step
# Epoch 12/50
# 32/32 - 5s - loss: 1.7939 - accuracy: 0.5324 - auc_20: 0.8259 - precision_20: 0.7265 - recall_20: 0.3340 - f1_score: 0.3730 - val_loss: 1.4788 - val_accuracy: 0.3595 - val_auc_20: 0.7125 - val_precision_20: 0.5409 - val_recall_20: 0.2338 - val_f1_score: 0.2685 - 5s/epoch - 154ms/step
# Epoch 13/50
# 32/32 - 5s - loss: 1.6878 - accuracy: 0.5806 - auc_20: 0.8234 - precision_20: 0.7856 - recall_20: 0.3743 - f1_score: 0.4188 - val_loss: 1.6478 - val_accuracy: 0.4892 - val_auc_20: 0.7306 - val_precision_20: 0.6017 - val_recall_20: 0.2849 - val_f1_score: 0.3250 - 5s/epoch - 153ms/step

# %% [markdown]
# #### Train RCNN

# %%
for train_index, val_index in kf.split(full_X):
    X_train, X_val = full_X[train_index], full_X[val_index]
    y_train, y_val = full_y[train_index], full_y[val_index]
    face_rcnn = build_RCNN(face_features, n_length, face_outputs)
    history = train(face_rcnn, X_train, y_train, X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 32/32 - 3s - loss: 26.0369 - accuracy: 0.3143 - auc_21: 0.5722 - precision_21: 0.3161 - recall_21: 0.3065 - f1_score: 0.2289 - val_loss: 1.9176 - val_accuracy: 0.2063 - val_auc_21: 0.4978 - val_precision_21: 0.1486 - val_recall_21: 0.1081 - val_f1_score: 0.1682 - 3s/epoch - 101ms/step
# Epoch 2/50
# 32/32 - 2s - loss: 8.6411 - accuracy: 0.2947 - auc_21: 0.5799 - precision_21: 0.2944 - recall_21: 0.2525 - f1_score: 0.2229 - val_loss: 1.4942 - val_accuracy: 0.0963 - val_auc_21: 0.4780 - val_precision_21: 0.2000 - val_recall_21: 0.0334 - val_f1_score: 0.0978 - 2s/epoch - 57ms/step
# Epoch 3/50
# 32/32 - 2s - loss: 4.9247 - accuracy: 0.3389 - auc_21: 0.6275 - precision_21: 0.3506 - recall_21: 0.2721 - f1_score: 0.2721 - val_loss: 1.3223 - val_accuracy: 0.2181 - val_auc_21: 0.6016 - val_precision_21: 0.4603 - val_recall_21: 0.0570 - val_f1_score: 0.1748 - 2s/epoch - 58ms/step
# Epoch 4/50
# 32/32 - 2s - loss: 7.9051 - accuracy: 0.3684 - auc_21: 0.6440 - precision_21: 0.3753 - recall_21: 0.3134 - f1_score: 0.2899 - val_loss: 1.3139 - val_accuracy: 0.3910 - val_auc_21: 0.6901 - val_precision_21: 0.3672 - val_recall_21: 0.0923 - val_f1_score: 0.2648 - 2s/epoch - 57ms/step
# Epoch 5/50
# 32/32 - 2s - loss: 3.5475 - accuracy: 0.3821 - auc_21: 0.6873 - precision_21: 0.4081 - recall_21: 0.2878 - f1_score: 0.2931 - val_loss: 1.1081 - val_accuracy: 0.4656 - val_auc_21: 0.7635 - val_precision_21: 0.4675 - val_recall_21: 0.2967 - val_f1_score: 0.2344 - 2s/epoch - 57ms/step
# Epoch 6/50
# 32/32 - 2s - loss: 4.4850 - accuracy: 0.3929 - auc_21: 0.7097 - precision_21: 0.4407 - recall_21: 0.3104 - f1_score: 0.2990 - val_loss: 1.3410 - val_accuracy: 0.2633 - val_auc_21: 0.6474 - val_precision_21: 0.4187 - val_recall_21: 0.1316 - val_f1_score: 0.2025 - 2s/epoch - 57ms/step
# Epoch 7/50
# 32/32 - 2s - loss: 7.1394 - accuracy: 0.3399 - auc_21: 0.6529 - precision_21: 0.3663 - recall_21: 0.3016 - f1_score: 0.2674 - val_loss: 2.3690 - val_accuracy: 0.2024 - val_auc_21: 0.5459 - val_precision_21: 0.1863 - val_recall_21: 0.1650 - val_f1_score: 0.1937 - 2s/epoch - 57ms/step
# Epoch 8/50
# 32/32 - 2s - loss: 4.3289 - accuracy: 0.3743 - auc_23: 0.6951 - precision_23: 0.3905 - recall_23: 0.3468 - f1_score: 0.2789 - val_loss: 2.1099 - val_accuracy: 0.1532 - val_auc_23: 0.4411 - val_precision_23: 0.1444 - val_recall_23: 0.1277 - val_f1_score: 0.1445 - 2s/epoch - 57ms/step
# Epoch 6/50
# 32/32 - 2s - loss: 4.5394 - accuracy: 0.4096 - auc_23: 0.7093 - precision_23: 0.4640 - recall_23: 0.3477 - f1_score: 0.3183 - val_loss: 3.8026 - val_accuracy: 0.2593 - val_auc_23: 0.4683 - val_precision_23: 0.2424 - val_recall_23: 0.2181 - val_f1_score: 0.2106 - 2s/epoch - 57ms/step
# Epoch 7/50
# 32/32 - 2s - loss: 5.1087 - accuracy: 0.4096 - auc_23: 0.6944 - precision_23: 0.4302 - recall_23: 0.3301 - f1_score: 0.3088 - val_loss: 2.1658 - val_accuracy: 0.2122 - val_auc_23: 0.5692 - val_precision_23: 0.1883 - val_recall_23: 0.1650 - val_f1_score: 0.1545 - 2s/epoch - 57ms/step
# Epoch 8/50
# 32/32 - 2s - loss: 3.7331 - accuracy: 0.3969 - auc_23: 0.7026 - precision_23: 0.4318 - recall_23: 0.3546 - f1_score: 0.2955 - val_loss: 2.0347 - val_accuracy: 0.2102 - val_auc_23: 0.5238 - val_precision_23: 0.4131 - val_recall_23: 0.1729 - val_f1_score: 0.1750 - 2s/epoch - 57ms/step
# Epoch 9/50
# 32/32 - 2s - loss: 4.8163 - accuracy: 0.4155 - auc_23: 0.7297 - precision_23: 0.4501 - recall_23: 0.3497 - f1_score: 0.3252 - val_loss: 1.9539 - val_accuracy: 0.2122 - val_auc_23: 0.5165 - val_precision_23: 0.2120 - val_recall_23: 0.1807 - val_f1_score: 0.2049 - 2s/epoch - 57ms/step
# Epoch 10/50
# 32/32 - 2s - loss: 5.7937 - accuracy: 0.3802 - auc_23: 0.6747 - precision_23: 0.3883 - recall_23: 0.3379 - f1_score: 0.3114 - val_loss: 3.0618 - val_accuracy: 0.3733 - val_auc_23: 0.6114 - val_precision_23: 0.3683 - val_recall_23: 0.3517 - val_f1_score: 0.2295 - 2s/epoch - 57ms/step
# Epoch 11/50
# 32/32 - 2s - loss: 5.4306 - accuracy: 0.4086 - auc_23: 0.6971 - precision_23: 0.4247 - recall_23: 0.3654 - f1_score: 0.3167 - val_loss: 3.1441 - val_accuracy: 0.1925 - val_auc_23: 0.5337 - val_precision_23: 0.1915 - val_recall_23: 0.1866 - val_f1_score: 0.1747 - 2s/epoch - 58ms/step

# %% [markdown]
# ## 2. Early Fusion - Fusion is performed at feature level
#
# Early fusion concatenates features at the input level, then all the work is on the classifier.
#
# My initial assumption is that perhaps early fusion is not the best idea because the face modality is missing about half the times (OpenFace could not capture facial action units from the videos), which makes the dataset smaller.
# I did not replace the missing facial values because I thought null values will bring no benefit (I assume?) and adding for example zero would mean the absence of action units which I'm afraid might actually "trick" the model in the case where a person has pain and the facial modality was not available because of technical issues, not because of an actual lack of pain.

# %% [markdown]
# ### About the data

# %%
early_X_train, early_X_test, early_y_train, early_y_test = load_earlyfusion_dataset('processed')
early_X = early_X_train.copy()
early_y = early_y_train.copy()

print(early_X_train.shape, early_y_train.shape)
print(early_X_test.shape, early_y_test.shape)

n_length, early_features, early_outputs = early_X_train.shape[2], early_X_train.shape[-1], early_y_train.shape[1]
# Out:
# (509, 1, 350, 48) (509, 4)
# (88, 1, 350, 48) (88, 4)

# %%
jitter_X = jitter(early_X, sigma=0.03)

# %%
reshaped_X = early_X.reshape((early_X.shape[0], early_X.shape[2], early_X.shape[-1]))
rotated_X = rotation(reshaped_X)
rotated_X = rotated_X.reshape((rotated_X.shape[0], 1, rotated_X.shape[1], rotated_X.shape[-1]))

# %%
augmented_X = np.concatenate((rotated_X, jitter_X), axis=0)
add_y = np.concatenate((early_y, early_y), axis=0)
full_X = np.concatenate((augmented_X, early_X), axis=0)
full_y = np.concatenate((add_y, early_y), axis=0)
full_X.shape
# Out:
# (1527, 1, 350, 48)

# %%
umild, lmoderate, lmild, umoderate = np.sum(early_y, axis=0)
total = umild + lmoderate + lmild + umoderate

weight_for_0 = (1 / umild) * (total / 2.0)
weight_for_1 = (1 / lmoderate) * (total / 2.0)
weight_for_2 = (1 / lmild) * (total / 2.0)
weight_for_3 = (1 / umoderate) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2, 3: weight_for_3}

print('Weight for Upper Body Pain Mild Level: {:.2f}'.format(weight_for_0))
print('Weight for Upper Body Pain Moderate Level: {:.2f}'.format(weight_for_3))
print('Weight for Lower Body Pain Mild Level: {:.2f}'.format(weight_for_2))
print('Weight for Lower Body Pain Moderate Level: {:.2f}'.format(weight_for_1))
# Out:
# Weight for Upper Body Pain Mild Level: 0.95
# Weight for Upper Body Pain Moderate Level: 127.25
# Weight for Lower Body Pain Mild Level: 1.33
# Weight for Lower Body Pain Moderate Level: 5.30

# %% [markdown]
# ### Train BiLSTM (with early fusion)

# %%
for train_index, val_index in kf.split(full_X):
    X_train, X_val = full_X[train_index], full_X[val_index]
    y_train, y_val = full_y[train_index], full_y[val_index]
    early_biConvLSTM = build_biConvLSTM(early_features, n_length, early_outputs)
    history = train(early_biConvLSTM, X_train, y_train, X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 32/32 - 45s - loss: 15.7884 - accuracy: 0.1965 - auc_24: 0.5527 - precision_24: 0.2446 - recall_24: 0.1444 - f1_score: 0.1627 - val_loss: 1.4234 - val_accuracy: 0.1022 - val_auc_24: 0.5659 - val_precision_24: 0.0723 - val_recall_24: 0.0118 - val_f1_score: 0.0653 - 45s/epoch - 1s/step
# Epoch 2/50
# 32/32 - 31s - loss: 3.1812 - accuracy: 0.0668 - auc_24: 0.4986 - precision_24: 0.3375 - recall_24: 0.0265 - f1_score: 0.0898 - val_loss: 1.6247 - val_accuracy: 0.0589 - val_auc_24: 0.4603 - val_precision_24: 0.3492 - val_recall_24: 0.0432 - val_f1_score: 0.0550 - 31s/epoch - 963ms/step
# 32/32 - 31s - loss: 2.3667 - accuracy: 0.1444 - auc_26: 0.4791 - precision_26: 0.8214 - recall_26: 0.0452 - f1_score: 0.1012 - val_loss: 1.4877 - val_accuracy: 0.1120 - val_auc_26: 0.6091 - val_precision_26: 0.3750 - val_recall_26: 0.0118 - val_f1_score: 0.0720 - 31s/epoch - 957ms/step

# %% [markdown]
# ### Train CNN+LSTM (with early fusion)

# %%
for train_index, val_index in kf.split(full_X):
    X_train, X_val = full_X[train_index], full_X[val_index]
    y_train, y_val = full_y[train_index], full_y[val_index]
    early_cnn = build_CNN(early_features, n_length, early_outputs)
    history = train(early_cnn, X_train, y_train, X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 32/32 - 8s - loss: 2.9675 - accuracy: 0.3477 - auc_27: 0.5641 - precision_27: 0.0000e+00 - recall_27: 0.0000e+00 - f1_score: 0.1780 - val_loss: 1.4015 - val_accuracy: 0.0963 - val_auc_27: 0.2214 - val_precision_27: 0.0000e+00 - val_recall_27: 0.0000e+00 - val_f1_score: 0.0439 - 8s/epoch - 240ms/step
# Epoch 2/50
# 32/32 - 2s - loss: 2.9559 - accuracy: 0.0236 - auc_27: 0.3377 - precision_27: 0.0000e+00 - recall_27: 0.0000e+00 - f1_score: 0.0384 - val_loss: 1.4007 - val_accuracy: 0.0020 - val_auc_27: 0.4528 - val_precision_27: 0.0000e+00 - val_recall_27: 0.0000e+00 - val_f1_score: 9.8039e-04 - 2s/epoch - 65ms/step
# Epoch 3/50
# 32/32 - 2s - loss: 2.9419 - accuracy: 0.0049 - auc_27: 0.4491 - precision_27: 0.0000e+00 - recall_27: 0.0000e+00 - f1_score: 0.0024 - val_loss: 1.3992 - val_accuracy: 0.0020 - val_auc_27: 0.4528 - val_precision_27: 0.0000e+00 - val_recall_27: 0.0000e+00 - val_f1_score: 9.8039e-04 - 2s/epoch - 66ms/step
# Epoch 4/50
# 32/32 - 2s - loss: 2.9580 - accuracy: 0.2210 - auc_27: 0.5766 - precision_27: 0.0000e+00 - recall_27: 0.0000e+00 - f1_score: 0.1508 - val_loss: 1.3926 - val_accuracy: 0.0020 - val_auc_27: 0.4528 - val_precision_27: 0.0000e+00 - val_recall_27: 0.0000e+00 - val_f1_score: 9.8039e-04 - 2s/epoch - 66ms/step
# Epoch 5/50
# 32/32 - 2s - loss: 2.9399 - accuracy: 0.0049 - auc_27: 0.3730 - precision_27: 0.0000e+00 - recall_27: 0.0000e+00 - f1_score: 0.0024 - val_loss: 1.4060 - val_accuracy: 0.0020 - val_auc_27: 0.3346 - val_precision_27: 0.0000e+00 - val_recall_27: 0.0000e+00 - val_f1_score: 9.8039e-04 - 2s/epoch - 65ms/step
# Epoch 6/50
# 32/32 - 2s - loss: 2.9379 - accuracy: 0.0049 - auc_27: 0.3465 - precision_27: 0.0000e+00 - recall_27: 0.0000e+00 - f1_score: 0.0024 - val_loss: 1.4091 - val_accuracy: 0.0020 - val_auc_27: 0.4528 - val_precision_27: 0.0000e+00 - val_recall_27: 0.0000e+00 - val_f1_score: 9.8039e-04 - 2s/epoch - 64ms/step
# Epoch 5/50
# 32/32 - 2s - loss: 2.3835 - accuracy: 0.3890 - auc_29: 0.7218 - precision_29: 0.0000e+00 - recall_29: 0.0000e+00 - f1_score: 0.1400 - val_loss: 1.2640 - val_accuracy: 0.3477 - val_auc_29: 0.6699 - val_precision_29: 0.0000e+00 - val_recall_29: 0.0000e+00 - val_f1_score: 0.1290 - 2s/epoch - 69ms/step
# Epoch 6/50
# 32/32 - 2s - loss: 2.4180 - accuracy: 0.2181 - auc_29: 0.5610 - precision_29: 0.0000e+00 - recall_29: 0.0000e+00 - f1_score: 0.1422 - val_loss: 1.2817 - val_accuracy: 0.3477 - val_auc_29: 0.5517 - val_precision_29: 0.0000e+00 - val_recall_29: 0.0000e+00 - val_f1_score: 0.1290 - 2s/epoch - 69ms/step
# Epoch 7/50
# 32/32 - 2s - loss: 2.3933 - accuracy: 0.3890 - auc_29: 0.7478 - precision_29: 0.0000e+00 - recall_29: 0.0000e+00 - f1_score: 0.1400 - val_loss: 1.2596 - val_accuracy: 0.3477 - val_auc_29: 0.7459 - val_precision_29: 0.0000e+00 - val_recall_29: 0.0000e+00 - val_f1_score: 0.1290 - 2s/epoch - 69ms/step
# Epoch 8/50
# 32/32 - 2s - loss: 2.3980 - accuracy: 0.3890 - auc_29: 0.6711 - precision_29: 0.0000e+00 - recall_29: 0.0000e+00 - f1_score: 0.1400 - val_loss: 1.2776 - val_accuracy: 0.3477 - val_auc_29: 0.5940 - val_precision_29: 0.0000e+00 - val_recall_29: 0.0000e+00 - val_f1_score: 0.1290 - 2s/epoch - 69ms/step
# Epoch 9/50
# 32/32 - 2s - loss: 2.4136 - accuracy: 0.3890 - auc_29: 0.5934 - precision_29: 0.0000e+00 - recall_29: 0.0000e+00 - f1_score: 0.1400 - val_loss: 1.2607 - val_accuracy: 0.3477 - val_auc_29: 0.5517 - val_precision_29: 0.0000e+00 - val_recall_29: 0.0000e+00 - val_f1_score: 0.1290 - 2s/epoch - 72ms/step
# Epoch 10/50
# 32/32 - 2s - loss: 2.3881 - accuracy: 0.1866 - auc_29: 0.5532 - precision_29: 0.0000e+00 - recall_29: 0.0000e+00 - f1_score: 0.1267 - val_loss: 1.2757 - val_accuracy: 0.3477 - val_auc_29: 0.6699 - val_precision_29: 0.0000e+00 - val_recall_29: 0.0000e+00 - val_f1_score: 0.1290 - 2s/epoch - 69ms/step
# Epoch 11/50
# 32/32 - 2s - loss: 2.3951 - accuracy: 0.3890 - auc_29: 0.7502 - precision_29: 0.0000e+00 - recall_29: 0.0000e+00 - f1_score: 0.1400 - val_loss: 1.2803 - val_accuracy: 0.3477 - val_auc_29: 0.6699 - val_precision_29: 0.0000e+00 - val_recall_29: 0.0000e+00 - val_f1_score: 0.1290 - 2s/epoch - 69ms/step

# %% [markdown]
# ### Train ConvLSTM (with early fusion)

# %%
for train_index, val_index in kf.split(full_X):
    X_train, X_val = full_X[train_index], full_X[val_index]
    y_train, y_val = full_y[train_index], full_y[val_index]
    early_convLSTM = build_convLSTM(early_features, n_length, early_outputs)
    history = train(early_convLSTM, X_train, y_train, X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 32/32 - 10s - loss: 18.8376 - accuracy: 0.2986 - auc_30: 0.5702 - precision_30: 0.3101 - recall_30: 0.2711 - f1_score: 0.2144 - val_loss: 5.2495 - val_accuracy: 0.2024 - val_auc_30: 0.4512 - val_precision_30: 0.2965 - val_recall_30: 0.1002 - val_f1_score: 0.1832 - 10s/epoch - 305ms/step
# Epoch 2/50
# 32/32 - 5s - loss: 25.1502 - accuracy: 0.1906 - auc_30: 0.5146 - precision_30: 0.3249 - recall_30: 0.1139 - f1_score: 0.1576 - val_loss: 4.5613 - val_accuracy: 0.3084 - val_auc_30: 0.5630 - val_precision_30: 0.3232 - val_recall_30: 0.1041 - val_f1_score: 0.1766 - 5s/epoch - 166ms/step
# Epoch 3/50
# 32/32 - 5s - loss: 5.5890 - accuracy: 0.2574 - auc_30: 0.5674 - precision_30: 0.4554 - recall_30: 0.1503 - f1_score: 0.2270 - val_loss: 4.6121 - val_accuracy: 0.1002 - val_auc_30: 0.4036 - val_precision_30: 0.3025 - val_recall_30: 0.0963 - val_f1_score: 0.0985 - 5s/epoch - 165ms/step
# Epoch 4/50
# 32/32 - 5s - loss: 5.0031 - accuracy: 0.2043 - auc_30: 0.5148 - precision_30: 0.5689 - recall_30: 0.1866 - f1_score: 0.2037 - val_loss: 3.8596 - val_accuracy: 0.1002 - val_auc_30: 0.4128 - val_precision_30: 0.3019 - val_recall_30: 0.0943 - val_f1_score: 0.0922 - 5s/epoch - 165ms/step
# Epoch 5/50
# 32/32 - 5s - loss: 5.3157 - accuracy: 0.1739 - auc_30: 0.5075 - precision_30: 0.4732 - recall_30: 0.1562 - f1_score: 0.1801 - val_loss: 4.3874 - val_accuracy: 0.1022 - val_auc_30: 0.4332 - val_precision_30: 0.2901 - val_recall_30: 0.0923 - val_f1_score: 0.1013 - 5s/epoch - 164ms/step
# Epoch 6/50
# 32/32 - 5s - loss: 5.6900 - accuracy: 0.1739 - auc_30: 0.5430 - precision_30: 0.4448 - recall_30: 0.1503 - f1_score: 0.1705 - val_loss: 4.1974 - val_accuracy: 0.1002 - val_auc_30: 0.4554 - val_precision_30: 0.3101 - val_recall_30: 0.0963 - val_f1_score: 0.0949 - 5s/epoch - 165ms/step
# Epoch 7/50
# 32/32 - 5s - loss: 5.1023 - accuracy: 0.1876 - auc_30: 0.5555 - precision_30: 0.5593 - recall_30: 0.1807 - f1_score: 0.2042 - val_loss: 4.3485 - val_accuracy: 0.1159 - val_auc_30: 0.4791 - val_precision_30: 0.3457 - val_recall_30: 0.1100 - val_f1_score: 0.1122 - 5s/epoch - 164ms/step
# Epoch 8/50
# 32/32 - 5s - loss: 3.6131 - accuracy: 0.2652 - auc_30: 0.6350 - precision_30: 0.6231 - recall_30: 0.1965 - f1_score: 0.2568 - val_loss: 3.7706 - val_accuracy: 0.4499 - val_auc_30: 0.6310 - val_precision_30: 0.4251 - val_recall_30: 0.2397 - val_f1_score: 0.1977 - 5s/epoch - 168ms/step
# Epoch 29/50
# 32/32 - 5s - loss: 2.9008 - accuracy: 0.5177 - auc_32: 0.7571 - precision_32: 0.7632 - recall_32: 0.2564 - f1_score: 0.5185 - val_loss: 3.9782 - val_accuracy: 0.3477 - val_auc_32: 0.5926 - val_precision_32: 0.3576 - val_recall_32: 0.1061 - val_f1_score: 0.1820 - 5s/epoch - 165ms/step
# Epoch 30/50
# 32/32 - 5s - loss: 1.9209 - accuracy: 0.5206 - auc_32: 0.7729 - precision_32: 0.7758 - recall_32: 0.2583 - f1_score: 0.4889 - val_loss: 3.8206 - val_accuracy: 0.3576 - val_auc_32: 0.6071 - val_precision_32: 0.3919 - val_recall_32: 0.1139 - val_f1_score: 0.2010 - 5s/epoch - 166ms/step

# %% [markdown]
# ### Train RCNN (with early fusion)

# %%
for train_index, val_index in kf.split(full_X):
    X_train, X_val = full_X[train_index], full_X[val_index]
    y_train, y_val = full_y[train_index], full_y[val_index]
    early_rcnn = build_RCNN(early_features, n_length, early_outputs)
    history = train(early_rcnn, X_train, y_train, X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 32/32 - 3s - loss: 33.6006 - accuracy: 0.3006 - auc_33: 0.5615 - precision_33: 0.2971 - recall_33: 0.2898 - f1_score: 0.2276 - val_loss: 36.2933 - val_accuracy: 0.1198 - val_auc_33: 0.4193 - val_precision_33: 0.1198 - val_recall_33: 0.1198 - val_f1_score: 0.0790 - 3s/epoch - 106ms/step
# Epoch 2/50
# 32/32 - 2s - loss: 59.6735 - accuracy: 0.2819 - auc_33: 0.5556 - precision_33: 0.2823 - recall_33: 0.2770 - f1_score: 0.2112 - val_loss: 14.3101 - val_accuracy: 0.3124 - val_auc_33: 0.5490 - val_precision_33: 0.3124 - val_recall_33: 0.3124 - val_f1_score: 0.2068 - 2s/epoch - 62ms/step
# Epoch 3/50
# 32/32 - 2s - loss: 46.6977 - accuracy: 0.3065 - auc_33: 0.5818 - precision_33: 0.3091 - recall_33: 0.3055 - f1_score: 0.2328 - val_loss: 18.0457 - val_accuracy: 0.2593 - val_auc_33: 0.5022 - val_precision_33: 0.2593 - val_recall_33: 0.2593 - val_f1_score: 0.1711 - 2s/epoch - 61ms/step
# Epoch 4/50
# 32/32 - 2s - loss: 46.1605 - accuracy: 0.3006 - auc_33: 0.5899 - precision_33: 0.2992 - recall_33: 0.2957 - f1_score: 0.2243 - val_loss: 13.4035 - val_accuracy: 0.4322 - val_auc_33: 0.6476 - val_precision_33: 0.4331 - val_recall_33: 0.4322 - val_f1_score: 0.2100 - 2s/epoch - 62ms/step
# Epoch 5/50
# 32/32 - 2s - loss: 32.7075 - accuracy: 0.3094 - auc_33: 0.5759 - precision_33: 0.3115 - recall_33: 0.3084 - f1_score: 0.2372 - val_loss: 10.5947 - val_accuracy: 0.4637 - val_auc_33: 0.6827 - val_precision_33: 0.4644 - val_recall_33: 0.4617 - val_f1_score: 0.2335 - 2s/epoch - 61ms/step
# Epoch 6/50
# Epoch 17/50
# 32/32 - 2s - loss: 50.2073 - accuracy: 0.3301 - auc_35: 0.5919 - precision_35: 0.3320 - recall_35: 0.3281 - f1_score: 0.2473 - val_loss: 14.9846 - val_accuracy: 0.3635 - val_auc_35: 0.5834 - val_precision_35: 0.3635 - val_recall_35: 0.3635 - val_f1_score: 0.2473 - 2s/epoch - 62ms/step

# %% [markdown]
# ## 3. Late Fusion - Fusion is performed at decision level
#
# In late fusion, I test two approaches, in both uni-modal classifiers are trained individually, and then either:
#
# - Their final dense (decision) layer is concatenated to produce the final prediction; or
#
# - Ensemble the uni-modal classifiers.
#
# Just as with early fusion, we have the issue that the face modality is missing about half of the times and therefore, I can only use late fusion if both modalities are present.

# %%
body_X_train, body_X_test, y_train, y_test = load_latefusion_dataset('processed', 'skeleton')
body_X = body_X_train.copy()
y = y_train.copy()

print(body_X_train.shape, y_train.shape)
print(body_X_test.shape, y_test.shape)

n_length, body_features, body_outputs = body_X_train.shape[2], body_X_train.shape[-1], y_train.shape[1]
# Out:
# (509, 1, 350, 38) (509, 4)
# (88, 1, 350, 38) (88, 4)

# %%
jitter_X = jitter(body_X, sigma=0.03)

# %%
reshaped_X = body_X.reshape((body_X.shape[0], body_X.shape[2], body_X.shape[-1]))
rotated_X = rotation(reshaped_X)
rotated_X = rotated_X.reshape((rotated_X.shape[0], 1, rotated_X.shape[1], rotated_X.shape[-1]))

# %%
augmented_X = np.concatenate((rotated_X, jitter_X), axis=0)
add_y = np.concatenate((y, y), axis=0)
body_X = np.concatenate((augmented_X, body_X), axis=0)
y = np.concatenate((add_y, y), axis=0) 
body_X.shape
# Out:
# (1527, 1, 350, 38)

# %%
jitter_X = jitter(face_X, sigma=0.03)

# %%
reshaped_X = face_X.reshape((face_X.shape[0], face_X.shape[2], face_X.shape[-1]))
rotated_X = rotation(reshaped_X)
rotated_X = rotated_X.reshape((rotated_X.shape[0], 1, rotated_X.shape[1], rotated_X.shape[-1]))

# %%
augmented_X = np.concatenate((rotated_X, jitter_X), axis=0)
face_X = np.concatenate((augmented_X, face_X), axis=0)
face_X.shape
# Out:
# (1527, 1, 350, 10)

# %%
umild, lmoderate, lmild, umoderate = np.sum(y, axis=0)
total = umild + lmoderate + lmild + umoderate

weight_for_0 = (1 / umild) * (total / 2.0)
weight_for_1 = (1 / lmoderate) * (total / 2.0)
weight_for_2 = (1 / lmild) * (total / 2.0)
weight_for_3 = (1 / umoderate) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2, 3: weight_for_3}

print('Weight for Upper Body Pain Mild Level: {:.2f}'.format(weight_for_0))
print('Weight for Upper Body Pain Moderate Level: {:.2f}'.format(weight_for_3))
print('Weight for Lower Body Pain Mild Level: {:.2f}'.format(weight_for_2))
print('Weight for Lower Body Pain Moderate Level: {:.2f}'.format(weight_for_1))
# Out:
# Weight for Upper Body Pain Mild Level: 0.95
# Weight for Upper Body Pain Moderate Level: 127.25
# Weight for Lower Body Pain Mild Level: 1.33
# Weight for Lower Body Pain Moderate Level: 5.30

# %% [markdown]
# ### BiLSTM (concatenate decision layer)

# %%
for train_index, val_index in kf.split(body_X):
    body_X_train, body_X_val = body_X[train_index], body_X[val_index]
    face_X_train, face_X_val = face_X[train_index], face_X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    biLSTM = build_fusioned_biConvLSTM(body_features, face_features, n_length, body_outputs)
    history = train_fusioned(biLSTM, body_X_train, face_X_train, y_train, body_X_val, face_X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 32/32 - 83s - loss: 10.6320 - accuracy: 0.3448 - auc_36: 0.6181 - precision_36: 0.3438 - recall_36: 0.2917 - f1_score: 0.2364 - val_loss: 3.2878 - val_accuracy: 0.2809 - val_auc_36: 0.5863 - val_precision_36: 0.2132 - val_recall_36: 0.1591 - val_f1_score: 0.1735 - 83s/epoch - 3s/step
# Epoch 2/50
# 32/32 - 62s - loss: 17.5692 - accuracy: 0.3409 - auc_36: 0.6278 - precision_36: 0.3439 - recall_36: 0.2672 - f1_score: 0.2517 - val_loss: 2.2327 - val_accuracy: 0.4008 - val_auc_36: 0.6789 - val_precision_36: 0.4228 - val_recall_36: 0.2692 - val_f1_score: 0.2584 - 62s/epoch - 2s/step
# Epoch 3/50
# 32/32 - 56s - loss: 6.6947 - accuracy: 0.3438 - auc_36: 0.6038 - precision_36: 0.3833 - recall_36: 0.2161 - f1_score: 0.2394 - val_loss: 2.5491 - val_accuracy: 0.3654 - val_auc_36: 0.6038 - val_precision_36: 0.2125 - val_recall_36: 0.0668 - val_f1_score: 0.2326 - 56s/epoch - 2s/step
# Epoch 4/50
# 32/32 - 56s - loss: 4.1735 - accuracy: 0.3212 - auc_36: 0.6456 - precision_36: 0.3902 - recall_36: 0.1640 - f1_score: 0.2549 - val_loss: 2.1440 - val_accuracy: 0.2967 - val_auc_36: 0.6344 - val_precision_36: 0.4103 - val_recall_36: 0.2200 - val_f1_score: 0.1819 - 56s/epoch - 2s/step
# Epoch 5/50
# 32/32 - 56s - loss: 3.7214 - accuracy: 0.3301 - auc_36: 0.6635 - precision_36: 0.4966 - recall_36: 0.2171 - f1_score: 0.2520 - val_loss: 2.0675 - val_accuracy: 0.2947 - val_auc_36: 0.6538 - val_precision_36: 0.4239 - val_recall_36: 0.1532 - val_f1_score: 0.1947 - 56s/epoch - 2s/step
# Epoch 6/50
# 32/32 - 56s - loss: 3.8536 - accuracy: 0.3615 - auc_36: 0.6835 - precision_36: 0.5214 - recall_36: 0.2397 - f1_score: 0.2691 - val_loss: 2.6505 - val_accuracy: 0.2417 - val_auc_36: 0.6064 - val_precision_36: 0.3533 - val_recall_36: 0.1277 - val_f1_score: 0.1706 - 56s/epoch - 2s/step
# Epoch 7/50
# 32/32 - 56s - loss: 3.8446 - accuracy: 0.3409 - auc_36: 0.6586 - precision_36: 0.4977 - recall_36: 0.2132 - f1_score: 0.2598 - val_loss: 2.4843 - val_accuracy: 0.2790 - val_auc_36: 0.6234 - val_precision_36: 0.3521 - val_recall_36: 0.1473 - val_f1_score: 0.2047 - 56s/epoch - 2s/step
# %% [markdown]
# ### CNN+LSTM (concatenate decision layer)

# %%
for train_index, val_index in kf.split(body_X):
    body_X_train, body_X_val = body_X[train_index], body_X[val_index]
    face_X_train, face_X_val = face_X[train_index], face_X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    CNNLSTM = build_fusioned_CNN(body_features, face_features, n_length, body_outputs)
    history = train_fusioned(CNNLSTM, body_X_train, face_X_train, y_train, body_X_val, face_X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 32/32 - 10s - loss: 3.3694 - accuracy: 0.3694 - auc_39: 0.7342 - precision_39: 0.0000e+00 - recall_39: 0.0000e+00 - f1_score: 0.1918 - val_loss: 1.1343 - val_accuracy: 0.5049 - val_auc_39: 0.7952 - val_precision_39: 0.0000e+00 - val_recall_39: 0.0000e+00 - val_f1_score: 0.1972 - 10s/epoch - 304ms/step
# Epoch 2/50
# 32/32 - 4s - loss: 3.0791 - accuracy: 0.1365 - auc_39: 0.5980 - precision_39: 0.0000e+00 - recall_39: 0.0000e+00 - f1_score: 0.0904 - val_loss: 1.3461 - val_accuracy: 0.0688 - val_auc_39: 0.5557 - val_precision_39: 0.0000e+00 - val_recall_39: 0.0000e+00 - val_f1_score: 0.0627 - 4s/epoch - 113ms/step
# Epoch 3/50
# 32/32 - 4s - loss: 2.7976 - accuracy: 0.2859 - auc_39: 0.6202 - precision_39: 0.0000e+00 - recall_39: 0.0000e+00 - f1_score: 0.2208 - val_loss: 1.2280 - val_accuracy: 0.2829 - val_auc_39: 0.7225 - val_precision_39: 0.0000e+00 - val_recall_39: 0.0000e+00 - val_f1_score: 0.1297 - 4s/epoch - 110ms/step
# Epoch 4/50
# 32/32 - 4s - loss: 2.9494 - accuracy: 0.2917 - auc_39: 0.5874 - precision_39: 0.0000e+00 - recall_39: 0.0000e+00 - f1_score: 0.2158 - val_loss: 1.3192 - val_accuracy: 0.3320 - val_auc_39: 0.6153 - val_precision_39: 0.0000e+00 - val_recall_39: 0.0000e+00 - val_f1_score: 0.1841 - 4s/epoch - 112ms/step
# Epoch 5/50
# 32/32 - 4s - loss: 2.7534 - accuracy: 0.3585 - auc_39: 0.6175 - precision_39: 0.6923 - recall_39: 0.0265 - f1_score: 0.2439 - val_loss: 1.3293 - val_accuracy: 0.2574 - val_auc_39: 0.5570 - val_precision_39: 0.4483 - val_recall_39: 0.0255 - val_f1_score: 0.1850 - 4s/epoch - 112ms/step
# Epoch 6/50
# 32/32 - 4s - loss: 2.5604 - accuracy: 0.3635 - auc_39: 0.6140 - precision_39: 0.6533 - recall_39: 0.0481 - f1_score: 0.2721 - val_loss: 1.2344 - val_accuracy: 0.3654 - val_auc_39: 0.6561 - val_precision_39: 0.4651 - val_recall_39: 0.0393 - val_f1_score: 0.2133 - 4s/epoch - 112ms/step
# Epoch 7/50
# Epoch 2/50
# 32/32 - 3s - loss: 2.4653 - accuracy: 0.3792 - auc_41: 0.6947 - precision_41: 0.0000e+00 - recall_41: 0.0000e+00 - f1_score: 0.1385 - val_loss: 1.2461 - val_accuracy: 0.1002 - val_auc_41: 0.5186 - val_precision_41: 0.0000e+00 - val_recall_41: 0.0000e+00 - val_f1_score: 0.0517 - 3s/epoch - 109ms/step
# Epoch 3/50
# 32/32 - 4s - loss: 2.4009 - accuracy: 0.3576 - auc_41: 0.7341 - precision_41: 0.0000e+00 - recall_41: 0.0000e+00 - f1_score: 0.1736 - val_loss: 1.2861 - val_accuracy: 0.3477 - val_auc_41: 0.5845 - val_precision_41: 0.0000e+00 - val_recall_41: 0.0000e+00 - val_f1_score: 0.1290 - 4s/epoch - 117ms/step
# Epoch 4/50
# 32/32 - 4s - loss: 2.5152 - accuracy: 0.3713 - auc_41: 0.6477 - precision_41: 0.0000e+00 - recall_41: 0.0000e+00 - f1_score: 0.1675 - val_loss: 1.2321 - val_accuracy: 0.3477 - val_auc_41: 0.6217 - val_precision_41: 0.0000e+00 - val_recall_41: 0.0000e+00 - val_f1_score: 0.1290 - 4s/epoch - 112ms/step
# Epoch 5/50
# 32/32 - 4s - loss: 2.4103 - accuracy: 0.1906 - auc_41: 0.5831 - precision_41: 0.0000e+00 - recall_41: 0.0000e+00 - f1_score: 0.1319 - val_loss: 1.2804 - val_accuracy: 0.3477 - val_auc_41: 0.6644 - val_precision_41: 0.0000e+00 - val_recall_41: 0.0000e+00 - val_f1_score: 0.1290 - 4s/epoch - 110ms/step
# Epoch 6/50
# 32/32 - 4s - loss: 2.3978 - accuracy: 0.3890 - auc_41: 0.7432 - precision_41: 0.0000e+00 - recall_41: 0.0000e+00 - f1_score: 0.1400 - val_loss: 1.2989 - val_accuracy: 0.3477 - val_auc_41: 0.6066 - val_precision_41: 0.0000e+00 - val_recall_41: 0.0000e+00 - val_f1_score: 0.1290 - 4s/epoch - 112ms/step
# Epoch 7/50
# 32/32 - 4s - loss: 2.3862 - accuracy: 0.2397 - auc_41: 0.5651 - precision_41: 0.0000e+00 - recall_41: 0.0000e+00 - f1_score: 0.1503 - val_loss: 1.2902 - val_accuracy: 0.1041 - val_auc_41: 0.5249 - val_precision_41: 0.0000e+00 - val_recall_41: 0.0000e+00 - val_f1_score: 0.0572 - 4s/epoch - 112ms/step
# Epoch 8/50
# 32/32 - 4s - loss: 2.4051 - accuracy: 0.3143 - auc_41: 0.6663 - precision_41: 0.0000e+00 - recall_41: 0.0000e+00 - f1_score: 0.1719 - val_loss: 1.2585 - val_accuracy: 0.3477 - val_auc_41: 0.7513 - val_precision_41: 0.0000e+00 - val_recall_41: 0.0000e+00 - val_f1_score: 0.1290 - 4s/epoch - 112ms/step
# Epoch 9/50
# 32/32 - 4s - loss: 2.4144 - accuracy: 0.3890 - auc_41: 0.7287 - precision_41: 0.0000e+00 - recall_41: 0.0000e+00 - f1_score: 0.1400 - val_loss: 1.2422 - val_accuracy: 0.3497 - val_auc_41: 0.5957 - val_precision_41: 0.0000e+00 - val_recall_41: 0.0000e+00 - val_f1_score: 0.1394 - 4s/epoch - 111ms/step
# Epoch 10/50
# 32/32 - 4s - loss: 2.4160 - accuracy: 0.2790 - auc_41: 0.5948 - precision_41: 0.0000e+00 - recall_41: 0.0000e+00 - f1_score: 0.1647 - val_loss: 1.2800 - val_accuracy: 0.3320 - val_auc_41: 0.6772 - val_precision_41: 0.0000e+00 - val_recall_41: 0.0000e+00 - val_f1_score: 0.1648 - 4s/epoch - 112ms/step
# Epoch 11/50
# 32/32 - 4s - loss: 2.3842 - accuracy: 0.1316 - auc_41: 0.5463 - precision_41: 0.0000e+00 - recall_41: 0.0000e+00 - f1_score: 0.0911 - val_loss: 1.2772 - val_accuracy: 0.2692 - val_auc_41: 0.5752 - val_precision_41: 0.0000e+00 - val_recall_41: 0.0000e+00 - val_f1_score: 0.1641 - 4s/epoch - 112ms/step

# %% [markdown]
# ### ConvLSTM (concatenate decision layer)

# %%
for train_index, val_index in kf.split(body_X):
    body_X_train, body_X_val = body_X[train_index], body_X[val_index]
    face_X_train, face_X_val = face_X[train_index], face_X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    convLSTM = build_fusioned_convLSTM(body_features, face_features, n_length, body_outputs)
    history = train_fusioned(convLSTM, body_X_train, face_X_train, y_train, body_X_val, face_X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 32/32 - 18s - loss: 22.9276 - accuracy: 0.3222 - auc_42: 0.6081 - precision_42: 0.3418 - recall_42: 0.3045 - f1_score: 0.2312 - val_loss: 4.6908 - val_accuracy: 0.2299 - val_auc_42: 0.5526 - val_precision_42: 0.2084 - val_recall_42: 0.1650 - val_f1_score: 0.1730 - 18s/epoch - 558ms/step
# Epoch 2/50
# 32/32 - 9s - loss: 16.9688 - accuracy: 0.3173 - auc_42: 0.5859 - precision_42: 0.3209 - recall_42: 0.2613 - f1_score: 0.2332 - val_loss: 4.5083 - val_accuracy: 0.3595 - val_auc_42: 0.6263 - val_precision_42: 0.3506 - val_recall_42: 0.2652 - val_f1_score: 0.2294 - 9s/epoch - 294ms/step
# Epoch 3/50
# 32/32 - 9s - loss: 10.9383 - accuracy: 0.2770 - auc_42: 0.5906 - precision_42: 0.2824 - recall_42: 0.2122 - f1_score: 0.2195 - val_loss: 4.6247 - val_accuracy: 0.3104 - val_auc_42: 0.5586 - val_precision_42: 0.2832 - val_recall_42: 0.2554 - val_f1_score: 0.1942 - 9s/epoch - 294ms/step
# Epoch 4/50
# 32/32 - 10s - loss: 6.6638 - accuracy: 0.3350 - auc_42: 0.6565 - precision_42: 0.4554 - recall_42: 0.2407 - f1_score: 0.2526 - val_loss: 3.6556 - val_accuracy: 0.1395 - val_auc_42: 0.5254 - val_precision_42: 0.1571 - val_recall_42: 0.1022 - val_f1_score: 0.1183 - 10s/epoch - 298ms/step
# 32/32 - 9s - loss: 2.4989 - accuracy: 0.6041 - auc_44: 0.8456 - precision_44: 0.7279 - recall_44: 0.4440 - f1_score: 0.5534 - val_loss: 2.9679 - val_accuracy: 0.4322 - val_auc_44: 0.7021 - val_precision_44: 0.4765 - val_recall_44: 0.2790 - val_f1_score: 0.2922 - 9s/epoch - 291ms/step
# Epoch 14/50
# 32/32 - 9s - loss: 2.1369 - accuracy: 0.6081 - auc_44: 0.8429 - precision_44: 0.7283 - recall_44: 0.4528 - f1_score: 0.4996 - val_loss: 3.7173 - val_accuracy: 0.3654 - val_auc_44: 0.6417 - val_precision_44: 0.3602 - val_recall_44: 0.2279 - val_f1_score: 0.2421 - 9s/epoch - 292ms/step

# %% [markdown]
# ### RCNN (concatenate decision layer)

# %%
for train_index, val_index in kf.split(body_X):
    body_X_train, body_X_val = body_X[train_index], body_X[val_index]
    face_X_train, face_X_val = face_X[train_index], face_X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    RCNN = build_fusioned_RCNN(body_features, face_features, n_length, body_outputs)
    history = train_fusioned(RCNN, body_X_train, face_X_train, y_train, body_X_val, face_X_val, y_val, epochs=epochs, batch_size=batch_size, class_weight=class_weight)
    plt.plot(history.history['loss'])
    plt.show()
# Out:
# Epoch 1/50
# 32/32 - 5s - loss: 83.2633 - accuracy: 0.2917 - auc_45: 0.5445 - precision_45: 0.2931 - recall_45: 0.2908 - f1_score: 0.2187 - val_loss: 29.8312 - val_accuracy: 0.4813 - val_auc_45: 0.6539 - val_precision_45: 0.4813 - val_recall_45: 0.4813 - val_f1_score: 0.1974 - 5s/epoch - 163ms/step
# Epoch 2/50
# 32/32 - 3s - loss: 17.8442 - accuracy: 0.3772 - auc_45: 0.5984 - precision_45: 0.3760 - recall_45: 0.3723 - f1_score: 0.2852 - val_loss: 5.3740 - val_accuracy: 0.2004 - val_auc_45: 0.5105 - val_precision_45: 0.1951 - val_recall_45: 0.1866 - val_f1_score: 0.1555 - 3s/epoch - 100ms/step
# Epoch 3/50
# 32/32 - 3s - loss: 17.4522 - accuracy: 0.3497 - auc_45: 0.6108 - precision_45: 0.3514 - recall_45: 0.3438 - f1_score: 0.2646 - val_loss: 17.2224 - val_accuracy: 0.5265 - val_auc_45: 0.6860 - val_precision_45: 0.5265 - val_recall_45: 0.5265 - val_f1_score: 0.1725 - 3s/epoch - 101ms/step
# Epoch 4/50
# 32/32 - 3s - loss: 42.8593 - accuracy: 0.3153 - auc_45: 0.5556 - precision_45: 0.3166 - recall_45: 0.3153 - f1_score: 0.2493 - val_loss: 16.2887 - val_accuracy: 0.3615 - val_auc_45: 0.5802 - val_precision_45: 0.3615 - val_recall_45: 0.3615 - val_f1_score: 0.1795 - 3s/epoch - 100ms/step
# Epoch 5/50
# 32/32 - 3s - loss: 40.8595 - accuracy: 0.4077 - auc_45: 0.6259 - precision_45: 0.4067 - recall_45: 0.4047 - f1_score: 0.3012 - val_loss: 40.5574 - val_accuracy: 0.2083 - val_auc_45: 0.4676 - val_precision_45: 0.2083 - val_recall_45: 0.2083 - val_f1_score: 0.1389 - 3s/epoch - 100ms/step
# Epoch 6/50
# 32/32 - 3s - loss: 2.0295 - accuracy: 0.5806 - auc_45: 0.8353 - precision_45: 0.5929 - recall_45: 0.5550 - f1_score: 0.5099 - val_loss: 3.6259 - val_accuracy: 0.4283 - val_auc_45: 0.7094 - val_precision_45: 0.4539 - val_recall_45: 0.3969 - val_f1_score: 0.3209 - 3s/epoch - 100ms/step
# Epoch 15/50
# 32/32 - 3s - loss: 1.9565 - accuracy: 0.6041 - auc_45: 0.8441 - precision_45: 0.6152 - recall_45: 0.5796 - f1_score: 0.5139 - val_loss: 2.7569 - val_accuracy: 0.4086 - val_auc_45: 0.7118 - val_precision_45: 0.4192 - val_recall_45: 0.3772 - val_f1_score: 0.3035 - 3s/epoch - 101ms/step
# Epoch 16/50
# 32/32 - 3s - loss: 1.4898 - accuracy: 0.5884 - auc_45: 0.8555 - precision_45: 0.6187 - recall_45: 0.5530 - f1_score: 0.5532 - val_loss: 2.5246 - val_accuracy: 0.4303 - val_auc_45: 0.7142 - val_precision_45: 0.4480 - val_recall_45: 0.3811 - val_f1_score: 0.3162 - 3s/epoch - 100ms/step
# Epoch 17/50
# 32/32 - 3s - loss: 1.6981 - accuracy: 0.6012 - auc_45: 0.8657 - precision_45: 0.6273 - recall_45: 0.5688 - f1_score: 0.5234 - val_loss: 2.4097 - val_accuracy: 0.4617 - val_auc_45: 0.7528 - val_precision_45: 0.4878 - val_recall_45: 0.4303 - val_f1_score: 0.3154 - 3s/epoch - 101ms/step
# Epoch 18/50
# 32/32 - 3s - loss: 7.1504 - accuracy: 0.5383 - auc_45: 0.7752 - precision_45: 0.5456 - recall_45: 0.5167 - f1_score: 0.4185 - val_loss: 4.9220 - val_accuracy: 0.4401 - val_auc_45: 0.7165 - val_precision_45: 0.4409 - val_recall_45: 0.4401 - val_f1_score: 0.3037 - 3s/epoch - 99ms/step
# Epoch 19/50
# 32/32 - 3s - loss: 5.2353 - accuracy: 0.5275 - auc_45: 0.7812 - precision_45: 0.5296 - recall_45: 0.5187 - f1_score: 0.4084 - val_loss: 13.1592 - val_accuracy: 0.2358 - val_auc_45: 0.5268 - val_precision_45: 0.2347 - val_recall_45: 0.2338 - val_f1_score: 0.1931 - 3s/epoch - 99ms/step
# Epoch 20/50
# 32/32 - 3s - loss: 4.5013 - accuracy: 0.5314 - auc_45: 0.7860 - precision_45: 0.5355 - recall_45: 0.5265 - f1_score: 0.4201 - val_loss: 3.1613 - val_accuracy: 0.5147 - val_auc_45: 0.7657 - val_precision_45: 0.5175 - val_recall_45: 0.4931 - val_f1_score: 0.3181 - 3s/epoch - 100ms/step
# Epoch 21/50
# 32/32 - 3s - loss: 2.2884 - accuracy: 0.5894 - auc_45: 0.8389 - precision_45: 0.6004 - recall_45: 0.5756 - f1_score: 0.5663 - val_loss: 3.0829 - val_accuracy: 0.5029 - val_auc_45: 0.7636 - val_precision_45: 0.5102 - val_recall_45: 0.4912 - val_f1_score: 0.2873 - 3s/epoch - 103ms/step
# Epoch 22/50
# Epoch 12/50
# 32/32 - 3s - loss: 10.7472 - accuracy: 0.5147 - auc_46: 0.7422 - precision_46: 0.5173 - recall_46: 0.5128 - f1_score: 0.3884 - val_loss: 31.2101 - val_accuracy: 0.2161 - val_auc_46: 0.4940 - val_precision_46: 0.2165 - val_recall_46: 0.2161 - val_f1_score: 0.1802 - 3s/epoch - 101ms/step
# Epoch 13/50
# 32/32 - 3s - loss: 17.2441 - accuracy: 0.5285 - auc_46: 0.7394 - precision_46: 0.5280 - recall_46: 0.5187 - f1_score: 0.4061 - val_loss: 24.3792 - val_accuracy: 0.2967 - val_auc_46: 0.5471 - val_precision_46: 0.2996 - val_recall_46: 0.2967 - val_f1_score: 0.2102 - 3s/epoch - 100ms/step
# Epoch 14/50
# 32/32 - 3s - loss: 11.1575 - accuracy: 0.4912 - auc_46: 0.7223 - precision_46: 0.4940 - recall_46: 0.4872 - f1_score: 0.3880 - val_loss: 11.6942 - val_accuracy: 0.3143 - val_auc_46: 0.5802 - val_precision_46: 0.3156 - val_recall_46: 0.3143 - val_f1_score: 0.2383 - 3s/epoch - 100ms/step
# Epoch 15/50
# 32/32 - 3s - loss: 4.3677 - accuracy: 0.5678 - auc_46: 0.7960 - precision_46: 0.5682 - recall_46: 0.5609 - f1_score: 0.4977 - val_loss: 7.0551 - val_accuracy: 0.2809 - val_auc_46: 0.5715 - val_precision_46: 0.2795 - val_recall_46: 0.2790 - val_f1_score: 0.2071 - 3s/epoch - 101ms/step
# Epoch 16/50
# 32/32 - 3s - loss: 6.3774 - accuracy: 0.5963 - auc_46: 0.8222 - precision_46: 0.6053 - recall_46: 0.5815 - f1_score: 0.4910 - val_loss: 25.0371 - val_accuracy: 0.1847 - val_auc_46: 0.4566 - val_precision_46: 0.1822 - val_recall_46: 0.1807 - val_f1_score: 0.1623 - 3s/epoch - 101ms/step
# Epoch 17/50
# 32/32 - 3s - loss: 5.7671 - accuracy: 0.5255 - auc_46: 0.7599 - precision_46: 0.5361 - recall_46: 0.5246 - f1_score: 0.4118 - val_loss: 5.1426 - val_accuracy: 0.3654 - val_auc_46: 0.6352 - val_precision_46: 0.3629 - val_recall_46: 0.3536 - val_f1_score: 0.2783 - 3s/epoch - 100ms/step
# Epoch 18/50
# 32/32 - 3s - loss: 5.4216 - accuracy: 0.5855 - auc_46: 0.8297 - precision_46: 0.6002 - recall_46: 0.5678 - f1_score: 0.4578 - val_loss: 6.8799 - val_accuracy: 0.3752 - val_auc_46: 0.6478 - val_precision_46: 0.3816 - val_recall_46: 0.3674 - val_f1_score: 0.2686 - 3s/epoch - 102ms/step
# Epoch 19/50
# 32/32 - 3s - loss: 2.2178 - accuracy: 0.5923 - auc_46: 0.8345 - precision_46: 0.6086 - recall_46: 0.5727 - f1_score: 0.4866 - val_loss: 3.9459 - val_accuracy: 0.4676 - val_auc_46: 0.7368 - val_precision_46: 0.4770 - val_recall_46: 0.4283 - val_f1_score: 0.3357 - 3s/epoch - 101ms/step
# Epoch 20/50
# 32/32 - 3s - loss: 3.7711 - accuracy: 0.6051 - auc_46: 0.8572 - precision_46: 0.6194 - recall_46: 0.5884 - f1_score: 0.4708 - val_loss: 8.1262 - val_accuracy: 0.3517 - val_auc_46: 0.5943 - val_precision_46: 0.3522 - val_recall_46: 0.3418 - val_f1_score: 0.2853 - 3s/epoch - 100ms/step
# Epoch 21/50
# 32/32 - 3s - loss: 2.4894 - accuracy: 0.6179 - auc_46: 0.8473 - precision_46: 0.6272 - recall_46: 0.5982 - f1_score: 0.4827 - val_loss: 3.7669 - val_accuracy: 0.4322 - val_auc_46: 0.7176 - val_precision_46: 0.4362 - val_recall_46: 0.4028 - val_f1_score: 0.3286 - 3s/epoch - 101ms/step
# Epoch 22/50
# 32/32 - 3s - loss: 1.7326 - accuracy: 0.6523 - auc_46: 0.8818 - precision_46: 0.6722 - recall_46: 0.6385 - f1_score: 0.6162 - val_loss: 3.1096 - val_accuracy: 0.4381 - val_auc_46: 0.7265 - val_precision_46: 0.4451 - val_recall_46: 0.4224 - val_f1_score: 0.3090 - 3s/epoch - 100ms/step
# Epoch 23/50
# 32/32 - 3s - loss: 1.5694 - accuracy: 0.6680 - auc_46: 0.8970 - precision_46: 0.6925 - recall_46: 0.6483 - f1_score: 0.6669 - val_loss: 3.0923 - val_accuracy: 0.4774 - val_auc_46: 0.7450 - val_precision_46: 0.5045 - val_recall_46: 0.4401 - val_f1_score: 0.3548 - 3s/epoch - 101ms/step
# Epoch 24/50
# 32/32 - 3s - loss: 1.5066 - accuracy: 0.6582 - auc_46: 0.8839 - precision_46: 0.6755 - recall_46: 0.6277 - f1_score: 0.5423 - val_loss: 2.7961 - val_accuracy: 0.4754 - val_auc_46: 0.7601 - val_precision_46: 0.4966 - val_recall_46: 0.4361 - val_f1_score: 0.3490 - 3s/epoch - 100ms/step
# Epoch 25/50
# 32/32 - 3s - loss: 2.1490 - accuracy: 0.6837 - auc_46: 0.8847 - precision_46: 0.7029 - recall_46: 0.6601 - f1_score: 0.5388 - val_loss: 7.0428 - val_accuracy: 0.3713 - val_auc_46: 0.6220 - val_precision_46: 0.3693 - val_recall_46: 0.3497 - val_f1_score: 0.2949 - 3s/epoch - 101ms/step
# Epoch 26/50
# 32/32 - 3s - loss: 1.8232 - accuracy: 0.6582 - auc_46: 0.8769 - precision_46: 0.6785 - recall_46: 0.6365 - f1_score: 0.5257 - val_loss: 3.5878 - val_accuracy: 0.4440 - val_auc_46: 0.7263 - val_precision_46: 0.4528 - val_recall_46: 0.4145 - val_f1_score: 0.3349 - 3s/epoch - 101ms/step
# Epoch 27/50
# 32/32 - 3s - loss: 1.4900 - accuracy: 0.6758 - auc_46: 0.8907 - precision_46: 0.6887 - recall_46: 0.6562 - f1_score: 0.6464 - val_loss: 3.2167 - val_accuracy: 0.5029 - val_auc_46: 0.7642 - val_precision_46: 0.5163 - val_recall_46: 0.4676 - val_f1_score: 0.3552 - 3s/epoch - 102ms/step
# Epoch 28/50
# 32/32 - 3s - loss: 1.5113 - accuracy: 0.7004 - auc_46: 0.9095 - precision_46: 0.7199 - recall_46: 0.6817 - f1_score: 0.5805 - val_loss: 3.7069 - val_accuracy: 0.4735 - val_auc_46: 0.7297 - val_precision_46: 0.4902 - val_recall_46: 0.4440 - val_f1_score: 0.3425 - 3s/epoch - 100ms/step
# Epoch 29/50
# 32/32 - 3s - loss: 1.7004 - accuracy: 0.6857 - auc_46: 0.8963 - precision_46: 0.6992 - recall_46: 0.6690 - f1_score: 0.5574 - val_loss: 2.9629 - val_accuracy: 0.4833 - val_auc_46: 0.7479 - val_precision_46: 0.4978 - val_recall_46: 0.4538 - val_f1_score: 0.3589 - 3s/epoch - 101ms/step
# Epoch 30/50
# 32/32 - 3s - loss: 1.3851 - accuracy: 0.6837 - auc_46: 0.8932 - precision_46: 0.6917 - recall_46: 0.6699 - f1_score: 0.6447 - val_loss: 3.3272 - val_accuracy: 0.5363 - val_auc_46: 0.7816 - val_precision_46: 0.5425 - val_recall_46: 0.4892 - val_f1_score: 0.3583 - 3s/epoch - 101ms/step
# Epoch 31/50
# 32/32 - 3s - loss: 1.3594 - accuracy: 0.6906 - auc_46: 0.9022 - precision_46: 0.7105 - recall_46: 0.6798 - f1_score: 0.6528 - val_loss: 3.5808 - val_accuracy: 0.4047 - val_auc_46: 0.6984 - val_precision_46: 0.4064 - val_recall_46: 0.3969 - val_f1_score: 0.2916 - 3s/epoch - 101ms/step
# Epoch 32/50
# 32/32 - 3s - loss: 1.1932 - accuracy: 0.7014 - auc_46: 0.9158 - precision_46: 0.7252 - recall_46: 0.6896 - f1_score: 0.7286 - val_loss: 2.4127 - val_accuracy: 0.5285 - val_auc_46: 0.7943 - val_precision_46: 0.5539 - val_recall_46: 0.5049 - val_f1_score: 0.3672 - 3s/epoch - 100ms/step
# Epoch 33/50
# 32/32 - 3s - loss: 0.8479 - accuracy: 0.7623 - auc_46: 0.9394 - precision_46: 0.7809 - recall_46: 0.7318 - f1_score: 0.7077 - val_loss: 2.5846 - val_accuracy: 0.5049 - val_auc_46: 0.7756 - val_precision_46: 0.5184 - val_recall_46: 0.4715 - val_f1_score: 0.3444 - 3s/epoch - 101ms/step
# Epoch 34/50
# 32/32 - 3s - loss: 0.8587 - accuracy: 0.7927 - auc_46: 0.9462 - precision_46: 0.8083 - recall_46: 0.7623 - f1_score: 0.7567 - val_loss: 2.4260 - val_accuracy: 0.5187 - val_auc_46: 0.7847 - val_precision_46: 0.5503 - val_recall_46: 0.4833 - val_f1_score: 0.3878 - 3s/epoch - 101ms/step
# Epoch 35/50
# 32/32 - 3s - loss: 1.0166 - accuracy: 0.7377 - auc_46: 0.9244 - precision_46: 0.7606 - recall_46: 0.7024 - f1_score: 0.7652 - val_loss: 3.0692 - val_accuracy: 0.4695 - val_auc_46: 0.7509 - val_precision_46: 0.4799 - val_recall_46: 0.4460 - val_f1_score: 0.3245 - 3s/epoch - 101ms/step
# Epoch 36/50
# Epoch 45/50
# 32/32 - 3s - loss: 7.1817 - accuracy: 0.6120 - auc_46: 0.8110 - precision_46: 0.6169 - recall_46: 0.6090 - f1_score: 0.4858 - val_loss: 7.8438 - val_accuracy: 0.5403 - val_auc_46: 0.7481 - val_precision_46: 0.5456 - val_recall_46: 0.5403 - val_f1_score: 0.3644 - 3s/epoch - 101ms/step
# Epoch 46/50
# 32/32 - 3s - loss: 20.6337 - accuracy: 0.5088 - auc_46: 0.6998 - precision_46: 0.5084 - recall_46: 0.5079 - f1_score: 0.3921 - val_loss: 12.6697 - val_accuracy: 0.3713 - val_auc_46: 0.6301 - val_precision_46: 0.3728 - val_recall_46: 0.3713 - val_f1_score: 0.2474 - 3s/epoch - 100ms/step
# Epoch 47/50
# 32/32 - 3s - loss: 16.6565 - accuracy: 0.5118 - auc_46: 0.7092 - precision_46: 0.5128 - recall_46: 0.5098 - f1_score: 0.3900 - val_loss: 9.2934 - val_accuracy: 0.5010 - val_auc_46: 0.7236 - val_precision_46: 0.5010 - val_recall_46: 0.5010 - val_f1_score: 0.2698 - 3s/epoch - 101ms/step
# Epoch 48/50
# 32/32 - 3s - loss: 18.5504 - accuracy: 0.5069 - auc_46: 0.7431 - precision_46: 0.5065 - recall_46: 0.5010 - f1_score: 0.3868 - val_loss: 9.6328 - val_accuracy: 0.3870 - val_auc_46: 0.6193 - val_precision_46: 0.3901 - val_recall_46: 0.3870 - val_f1_score: 0.2843 - 3s/epoch - 101ms/step
# Epoch 49/50
# 32/32 - 3s - loss: 26.1195 - accuracy: 0.4921 - auc_46: 0.7027 - precision_46: 0.4926 - recall_46: 0.4902 - f1_score: 0.3908 - val_loss: 16.0058 - val_accuracy: 0.5108 - val_auc_46: 0.7015 - val_precision_46: 0.5108 - val_recall_46: 0.5108 - val_f1_score: 0.3057 - 3s/epoch - 102ms/step
# Epoch 50/50
# 32/32 - 3s - loss: 50.3400 - accuracy: 0.4764 - auc_46: 0.6775 - precision_46: 0.4768 - recall_46: 0.4754 - f1_score: 0.3603 - val_loss: 25.2541 - val_accuracy: 0.4637 - val_auc_46: 0.6447 - val_precision_46: 0.4637 - val_recall_46: 0.4637 - val_f1_score: 0.3177 - 3s/epoch - 99ms/step
# Epoch 1/50
# 32/32 - 5s - loss: 83.5556 - accuracy: 0.2908 - auc_47: 0.5483 - precision_47: 0.2916 - recall_47: 0.2908 - f1_score: 0.2085 - val_loss: 18.9757 - val_accuracy: 0.3831 - val_auc_47: 0.5885 - val_precision_47: 0.3831 - val_recall_47: 0.3831 - val_f1_score: 0.1836 - 5s/epoch - 165ms/step
# Epoch 2/50
# 32/32 - 3s - loss: 40.0940 - accuracy: 0.3094 - auc_47: 0.5522 - precision_47: 0.3109 - recall_47: 0.3084 - f1_score: 0.2274 - val_loss: 41.1070 - val_accuracy: 0.1041 - val_auc_47: 0.3442 - val_precision_47: 0.1041 - val_recall_47: 0.1041 - val_f1_score: 0.0875 - 3s/epoch - 101ms/step
# 32/32 - 3s - loss: 1.9520 - accuracy: 0.6513 - auc_47: 0.8774 - precision_47: 0.6596 - recall_47: 0.6375 - f1_score: 0.5225 - val_loss: 3.1373 - val_accuracy: 0.5403 - val_auc_47: 0.8055 - val_precision_47: 0.5422 - val_recall_47: 0.5305 - val_f1_score: 0.4069 - 3s/epoch - 101ms/step
# Epoch 28/50
# 32/32 - 3s - loss: 1.1884 - accuracy: 0.6955 - auc_47: 0.9159 - precision_47: 0.7020 - recall_47: 0.6827 - f1_score: 0.6793 - val_loss: 3.2877 - val_accuracy: 0.4813 - val_auc_47: 0.7622 - val_precision_47: 0.4927 - val_recall_47: 0.4617 - val_f1_score: 0.3681 - 3s/epoch - 101ms/step
# Epoch 29/50
# 32/32 - 3s - loss: 1.1234 - accuracy: 0.6807 - auc_47: 0.9128 - precision_47: 0.6907 - recall_47: 0.6690 - f1_score: 0.7545 - val_loss: 2.6101 - val_accuracy: 0.5481 - val_auc_47: 0.8064 - val_precision_47: 0.5708 - val_recall_47: 0.5305 - val_f1_score: 0.4079 - 3s/epoch - 101ms/step
# Epoch 30/50
# 32/32 - 3s - loss: 1.0811 - accuracy: 0.7220 - auc_47: 0.9246 - precision_47: 0.7360 - recall_47: 0.7122 - f1_score: 0.7031 - val_loss: 3.1416 - val_accuracy: 0.5010 - val_auc_47: 0.7655 - val_precision_47: 0.5077 - val_recall_47: 0.4558 - val_f1_score: 0.4031 - 3s/epoch - 101ms/step

# %% [markdown]
# ### Convert Uni-modal Approaches to Ensemble Members

# %%
biLSTM_body_member = KerasMember(name="Body Model", keras_model=body_biConvLSTM, train_batches=(body_X_train, y_train), val_batches=(body_X_test, y_test))
biLSTM_face_member = KerasMember(name="Face Model", keras_model=face_biConvLSTM, train_batches=(face_X_train, y_train), val_batches=(face_X_test, y_test))

# %%
cnn_body_member = KerasMember(name="Body Model", keras_model=body_cnn, train_batches=(body_X_train, y_train), val_batches=(body_X_test, y_test))
cnn_face_member = KerasMember(name="Face Model", keras_model=face_cnn, train_batches=(face_X_train, y_train), val_batches=(face_X_test, y_test))

# %%
convLSTM_body_member = KerasMember(name="Body Model", keras_model=body_convLSTM, train_batches=(body_X_train, y_train), val_batches=(body_X_test, y_test))
convLSTM_face_member = KerasMember(name="Face Model", keras_model=face_convLSTM, train_batches=(face_X_train, y_train), val_batches=(face_X_test, y_test))

# %%
rcnn_body_member = KerasMember(name="Body Model", keras_model=body_rcnn, train_batches=(body_X_train, y_train), val_batches=(body_X_test, y_test))
rcnn_face_member = KerasMember(name="Face Model", keras_model=face_rcnn, train_batches=(face_X_train, y_train), val_batches=(face_X_test, y_test))

# %% [markdown]
# ### Dirichlet Markov Ensemble with weighted soft voting

# %%
biLSTM_dirichletEnsemble = DirichletEnsemble()
biLSTM_dirichletEnsemble.add_member(biLSTM_body_member)
biLSTM_dirichletEnsemble.add_member(biLSTM_face_member)
biLSTM_dirichletEnsemble.fit()

# %%
cnn_dirichletEnsemble = DirichletEnsemble()
cnn_dirichletEnsemble.add_member(cnn_body_member)
cnn_dirichletEnsemble.add_member(cnn_face_member)
cnn_dirichletEnsemble.fit()

# %%
convLSTM_dirichletEnsemble = DirichletEnsemble()
convLSTM_dirichletEnsemble.add_member(convLSTM_body_member)
convLSTM_dirichletEnsemble.add_member(convLSTM_face_member)
convLSTM_dirichletEnsemble.fit()

# %%
rcnn_dirichletEnsemble = DirichletEnsemble()
rcnn_dirichletEnsemble.add_member(rcnn_body_member)
rcnn_dirichletEnsemble.add_member(rcnn_face_member)
rcnn_dirichletEnsemble.fit()

# %% [markdown]
# ## Performance Evaluation on Test set

# %% [markdown]
# ### Uni-Modal (only Body/Skeleton data)

# %%
_, acc, auc, precision, recall, f1 = body_biConvLSTM.evaluate(full_body_X_test, full_body_y_test, verbose=0)
print('Bidirectional LSTM:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# Bidirectional LSTM:
# Accuracy: 18.89% - ROC/AUC: 0.44 - Precision: 0.00 - Recall: 0.00, F1 score: 0.14

# %%
_, acc, auc, precision, recall, f1 = body_cnn.evaluate(full_body_X_test, full_body_y_test, verbose=0)
print('CNN+LSTM:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# CNN+LSTM:
# Accuracy: 16.67% - ROC/AUC: 0.37 - Precision: 0.00 - Recall: 0.00, F1 score: 0.07

# %%
_, acc, auc, precision, recall, f1 = body_convLSTM.evaluate(full_body_X_test, full_body_y_test, verbose=0)
print('Convolutional LSTM:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# Convolutional LSTM:
# Accuracy: 16.67% - ROC/AUC: 0.39 - Precision: 0.00 - Recall: 0.00, F1 score: 0.07

# %%
_, acc, auc, precision, recall, f1 = body_rcnn.evaluate(full_body_X_test, full_body_y_test, verbose=0)
print('RCNN:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# RCNN:
# Accuracy: 13.33% - ROC/AUC: 0.38 - Precision: 0.13 - Recall: 0.09, F1 score: 0.09

# %% [markdown]
# ### Uni-Modal (only Facial Expression/Action Units)

# %%
_, acc, auc, precision, recall, f1 = face_biConvLSTM.evaluate(face_X_test, face_y_test, verbose=0)
print('Bidirectional LSTM:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# Bidirectional LSTM:
# Accuracy: 19.32% - ROC/AUC: 0.48 - Precision: 0.33 - Recall: 0.16, F1 score: 0.17

# %%
_, acc, auc, precision, recall, f1 = face_cnn.evaluate(face_X_test, face_y_test, verbose=0)
print('CNN+LSTM:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# CNN+LSTM:
# Accuracy: 17.05% - ROC/AUC: 0.39 - Precision: 0.00 - Recall: 0.00, F1 score: 0.08

# %%
_, acc, auc, precision, recall, f1 = face_convLSTM.evaluate(face_X_test, face_y_test, verbose=0)
print('Convolutional LSTM:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# Convolutional LSTM:
# Accuracy: 14.77% - ROC/AUC: 0.50 - Precision: 0.24 - Recall: 0.14, F1 score: 0.11

# %%
_, acc, auc, precision, recall, f1 = face_rcnn.evaluate(face_X_test, face_y_test, verbose=0)
print('RCNN:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# RCNN:
# Accuracy: 29.55% - ROC/AUC: 0.54 - Precision: 0.30 - Recall: 0.30, F1 score: 0.21

# %% [markdown]
# ### Early Fusion (Feature Level)

# %%
_, acc, auc, precision, recall, f1 = early_biConvLSTM.evaluate(early_X_test, early_y_test, verbose=0)
print('Bidirectional LSTM:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# Bidirectional LSTM:
# Accuracy: 17.05% - ROC/AUC: 0.49 - Precision: 0.00 - Recall: 0.00, F1 score: 0.07

# %%
_, acc, auc, precision, recall, f1 = early_cnn.evaluate(early_X_test, early_y_test, verbose=0)
print('CNN+LSTM:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# CNN+LSTM:
# Accuracy: 14.77% - ROC/AUC: 0.39 - Precision: 0.00 - Recall: 0.00, F1 score: 0.06

# %%
_, acc, auc, precision, recall, f1 = early_convLSTM.evaluate(early_X_test, early_y_test, verbose=0)
print('Convolutional LSTM:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# Convolutional LSTM:
# Accuracy: 15.91% - ROC/AUC: 0.37 - Precision: 0.00 - Recall: 0.00, F1 score: 0.10

# %%
_, acc, auc, precision, recall, f1 = early_rcnn.evaluate(early_X_test, early_y_test, verbose=0)
print('RCNN:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# RCNN:
# Accuracy: 13.64% - ROC/AUC: 0.42 - Precision: 0.14 - Recall: 0.14, F1 score: 0.06

# %% [markdown]
# ### Late Fusion (Decision Level)

# %%
_, acc, auc, precision, recall, f1 = biLSTM.evaluate([body_X_test, face_X_test], y_test, verbose=0)
print('Bidirectional LSTM:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# Bidirectional LSTM:
# Accuracy: 14.77% - ROC/AUC: 0.47 - Precision: 0.21 - Recall: 0.11, F1 score: 0.13

# %%
_, acc, auc, precision, recall, f1 = CNNLSTM.evaluate([body_X_test, face_X_test], y_test, verbose=0)
print('CNN+LSTM:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# CNN+LSTM:
# Accuracy: 21.59% - ROC/AUC: 0.38 - Precision: 0.00 - Recall: 0.00, F1 score: 0.16

# %%
_, acc, auc, precision, recall, f1 = convLSTM.evaluate([body_X_test, face_X_test], y_test, verbose=0)
print('Convolutional LSTM:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# Convolutional LSTM:
# Accuracy: 15.91% - ROC/AUC: 0.46 - Precision: 0.27 - Recall: 0.16, F1 score: 0.09

# %%
_, acc, auc, precision, recall, f1 = RCNN.evaluate([body_X_test, face_X_test], y_test, verbose=0)
print('RCNN:')
print('Accuracy: {:.2f}% - ROC/AUC: {:.2f} - Precision: {:.2f} - Recall: {:.2f}, F1 score: {:.2f}'.format(acc * 100, auc, precision, recall, f1))
# Out:
# RCNN:
# Accuracy: 20.45% - ROC/AUC: 0.45 - Precision: 0.22 - Recall: 0.20, F1 score: 0.18

# %%
print('BiLSTM Dirichlet Markov Ensemble:')
d = biLSTM_dirichletEnsemble.describe()
# Out:
# BiLSTM Dirichlet Markov Ensemble:
# Body Model (weight: 0.9449)
# Face Model (weight: 0.0551)
# Accuracy: 26.14% - ROC/AUC: 0.62 - Precision: 0.23 - Recall: 0.32 - F1 score: 0.23

# %%
print('CNN+LSTM Dirichlet Markov Ensemble:')
d = cnn_dirichletEnsemble.describe()
# Out:
# CNN+LSTM Dirichlet Markov Ensemble:
# Body Model (weight: 0.9998)
# Face Model (weight: 0.0002)
# Accuracy: 17.05% - ROC/AUC: 0.42 - Precision: 0.04 - Recall: 0.25 - F1 score: 0.08

# %%
print('ConvLSTM Dirichlet Markov Ensemble:')
d = convLSTM_dirichletEnsemble.describe()
# Out:
# ConvLSTM Dirichlet Markov Ensemble:
# Body Model (weight: 0.0285)
# Face Model (weight: 0.9715)
# Accuracy: 25.00% - ROC/AUC: 0.62 - Precision: 0.26 - Recall: 0.37 - F1 score: 0.20

# %%
print('RCNN Dirichlet Markov Ensemble:')
d = rcnn_dirichletEnsemble.describe()
# Out:
# RCNN Dirichlet Markov Ensemble:
# Body Model (weight: 0.0094)
# Face Model (weight: 0.9906)
# Accuracy: 29.55% - ROC/AUC: 0.59 - Precision: 0.23 - Recall: 0.33 - F1 score: 0.23
